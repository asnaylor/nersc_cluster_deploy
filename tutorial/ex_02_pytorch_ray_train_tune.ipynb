# %% [markdown]
# # NERSC Cluster Deploy Tutorial: Tuning Hyperparameters of a Distributed PyTorch Model with PBT using Ray Train & Tune
#
# 📖 [Back to Table of Contents](../README.md)<br>
# <!-- ⬅ [Previous notebook](./ex_01_pytorch_ray_hvd.ipynb) <br> -->
# <!-- ➡ [Next notebook](./ex_02_tensorflow_ray_train_tune.ipynb) <br> -->
#
# ----
#
#
# ## Introduction
#
# We are going to run an example Ray Train & Tune code. This example looks at tunning hyperparameters of a distrbuted PyTorch Model with PBT. This tutorial is following the code in this example: https://docs.ray.io/en/latest/train/examples/pytorch/tune_cifar_torch_pbt_example.html
#
# > **Note**:
# > To setup the environment for the notebook, execute on command line: `./setup.sh 2` then select the kernel `pytorch-1.13.1` in the notebook
#
# This Ray cluster will be setup using the NERSC PyTorch module and deployed on Perlmutter.

# %% [markdown]
# # Starting Ray Cluster
#
# ## Superfacility API
#
# To deploy the Ray cluster via the NERSC Superfacility API you require a valid API client.
#
# To create a valid client visit your profile page in [Iris](https://iris.nersc.gov/):
#
# <img src="img/iris_profile_header.png" width="800" />
#
# Then scroll down to the **Superfacility API Clients** section and click the "+ New Client" button which will produce this window:
#
# <img src="img/new_sf_api_client.png" width="400" />
#
# To submit and deploy a Ray cluster we require the highest security level (<span style="color:red">RED</span>). **[This client id is valid for 2 days]**
#
# Once created then saved the `client_id` string and `private_key` dictionary (you can also save the private key in PEM format) ready for use with the `SuperfacilityAPI` library.
#
# > **Note**:
# > This step should only be repeated if your client has expired
#
#
# For more information about the NERSC Superfacility API visit the [documenation](https://docs.nersc.gov/services/sfapi/).

# %%
from SuperfacilityAPI import SuperfacilityAPI, SuperfacilityAccessToken
from utility import load_secrets

# Replace with your client id string and private key dictionary
client_id, private_key = load_secrets()
# client_id = "<your client id string>"
# private_key = "<your private key dict>"

api_key = SuperfacilityAccessToken(
    client_id = client_id,
    private_key = private_key
)
sfp_api = SuperfacilityAPI(api_key)

# %% [markdown]
# ## Creating Ray Cluster
#
# To create a ray cluster on NERSC compute nodes, execute the `deploy_ray_cluster` function with your desired slurm sbatch options.

# %%
from nersc_cluster_deploy import deploy_ray_cluster
from utility import user_account

slurm_options = {
    'qos': 'debug',
    'account': user_account(),
    'nodes': '3',
    't': '00:30:00'
}
site = 'perlmutter'
module_load = 'pytorch/1.13.1'

job = deploy_ray_cluster(
    sfp_api,
    slurm_options,
    site,
    job_setup = [f'module load {module_load}']
)

# %% [markdown]
# Now the job has been submitted, check on the job status

# %%
import os
import pandas as pd
sqs_table = sfp_api.get_jobs(site=site, user=os.getlogin(), sacct=False)
sqs_df = pd.DataFrame(sqs_table['output'])
sqs_df
# Out:
#      account tres_per_node min_cpus min_tmp_disk             end_time  \
# 0  dasrepo_g           N/A      128            0  2023-03-21T10:54:12
#
#           features  group over_subscribe    jobid    name  ... partition  \
# 0  gpu&a100&hbm40g  75235             NO  6304042  sbatch  ...  gpu_ss11
#
#             nodelist(reason)           start_time    state    uid  \
# 0  nid[001164,001361,001364]  2023-03-21T10:24:12  RUNNING  75235
#
#            submit_time licenses core_spec schednodes               work_dir
# 0  2023-03-21T10:19:37     u2:1       N/A     (null)  /global/u2/a/asnaylor
#
# [1 rows x 49 columns]

# %% [markdown]
# Check job log

# %%
# !cat ~/slurm-{job['jobid']}.out
# Out:
# Warning: This is an experimental release of NCCL with an OFI plugin for use with libfabric on Perlmutter.
# In case of issues, please refer to our known issues: https://docs.nersc.gov/current/
# and open a help ticket if your issue is not listed: https://help.nersc.gov/
# [slurm] - Starting Ray HEAD
# 2023-03-21 10:24:24,850	INFO usage_lib.py:435 -- Usage stats collection is disabled.
# 2023-03-21 10:24:24,850	INFO scripts.py:710 -- Local node IP: nid001164
# 2023-03-21 10:24:26,520	SUCC scripts.py:747 -- --------------------
# 2023-03-21 10:24:26,520	SUCC scripts.py:748 -- Ray runtime started.
# 2023-03-21 10:24:26,520	SUCC scripts.py:749 -- --------------------
# 2023-03-21 10:24:26,520	INFO scripts.py:751 -- Next steps
# 2023-03-21 10:24:26,520	INFO scripts.py:752 -- To connect to this Ray runtime from another node, run
# 2023-03-21 10:24:26,520	INFO scripts.py:755 --   ray start --address='nid001164:6379'
# 2023-03-21 10:24:26,520	INFO scripts.py:771 -- Alternatively, use the following Python code:
# 2023-03-21 10:24:26,520	INFO scripts.py:773 -- import ray
# 2023-03-21 10:24:26,520	INFO scripts.py:777 -- ray.init(address='auto', _node_ip_address='nid001164')
# 2023-03-21 10:24:26,520	INFO scripts.py:790 -- To see the status of the cluster, use
# 2023-03-21 10:24:26,520	INFO scripts.py:791 --   ray status
# 2023-03-21 10:24:26,520	INFO scripts.py:794 -- To monitor and debug Ray, view the dashboard at
# 2023-03-21 10:24:26,520	INFO scripts.py:795 --   127.0.0.1:8265
# 2023-03-21 10:24:26,520	INFO scripts.py:801 -- If connection fails, check your firewall settings and network configuration.
# 2023-03-21 10:24:26,520	INFO scripts.py:809 -- To terminate the Ray runtime, run
# 2023-03-21 10:24:26,520	INFO scripts.py:810 --   ray stop
# 2023-03-21 10:24:26,520	INFO scripts.py:888 -- --block
# 2023-03-21 10:24:26,520	INFO scripts.py:889 -- This command will now block forever until terminated by a signal.
# 2023-03-21 10:24:26,520	INFO scripts.py:892 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# [slurm] - Starting up prometheus
# [slurm] - Starting up grafana
# ts=2023-03-21T17:24:36.734Z caller=main.go:512 level=info msg="No time or size retention was set so using the default time retention" duration=15d
# ts=2023-03-21T17:24:36.734Z caller=main.go:556 level=info msg="Starting Prometheus Server" mode=server version="(version=2.42.0, branch=HEAD, revision=225c61122d88b01d1f0eaaee0e05b6f3e0567ac0)"
# ts=2023-03-21T17:24:36.734Z caller=main.go:561 level=info build_context="(go=go1.19.5, platform=linux/amd64, user=root@c67d48967507, date=20230201-07:53:32)"
# ts=2023-03-21T17:24:36.734Z caller=main.go:562 level=info host_details="(Linux 5.14.21-150400.24.46_12.0.63-cray_shasta_c #1 SMP Fri Mar 3 22:39:37 UTC 2023 (6e164f9) x86_64 nid001164 )"
# ts=2023-03-21T17:24:36.734Z caller=main.go:563 level=info fd_limits="(soft=131072, hard=131072)"
# ts=2023-03-21T17:24:36.734Z caller=main.go:564 level=info vm_limits="(soft=unlimited, hard=unlimited)"
# ts=2023-03-21T17:24:36.742Z caller=web.go:561 level=info component=web msg="Start listening for connections" address=0.0.0.0:9090
# ts=2023-03-21T17:24:36.742Z caller=main.go:993 level=info msg="Starting TSDB ..."
# ts=2023-03-21T17:24:36.743Z caller=tls_config.go:232 level=info component=web msg="Listening on" address=[::]:9090
# ts=2023-03-21T17:24:36.743Z caller=tls_config.go:235 level=info component=web msg="TLS is disabled." http2=false address=[::]:9090
# ts=2023-03-21T17:24:36.743Z caller=repair.go:56 level=info component=tsdb msg="Found healthy block" mint=1678495272962 maxt=1678507200000 ulid=01GVC880H9YDH3FZJ86PN45N1V
# ts=2023-03-21T17:24:36.746Z caller=repair.go:56 level=info component=tsdb msg="Found healthy block" mint=1678653454572 maxt=1678680000000 ulid=01GVHDBJ6HGS5BQZ6693DT7TFW
# ts=2023-03-21T17:24:36.746Z caller=repair.go:56 level=info component=tsdb msg="Found healthy block" mint=1678842906609 maxt=1678845600000 ulid=01GVKHWQP6M03AABSD3G58SEHC
# ts=2023-03-21T17:24:36.747Z caller=repair.go:56 level=info component=tsdb msg="Found healthy block" mint=1678845601276 maxt=1678852800000 ulid=01GVKHWQR3CNQJFVB6THZ3NRJX
# ts=2023-03-21T17:24:36.748Z caller=repair.go:56 level=info component=tsdb msg="Found healthy block" mint=1678823688693 maxt=1678831200000 ulid=01GVKHWQTZ39EA4SN26SH3B93N
# ts=2023-03-21T17:24:36.770Z caller=head.go:564 level=info component=tsdb msg="Replaying on-disk memory mappable chunks if any"
# ts=2023-03-21T17:24:36.770Z caller=head.go:608 level=info component=tsdb msg="On-disk memory mappable chunks replay completed" duration=1.513µs
# ts=2023-03-21T17:24:36.770Z caller=head.go:614 level=info component=tsdb msg="Replaying WAL, this may take a while"
# ts=2023-03-21T17:24:36.811Z caller=head.go:650 level=info component=tsdb msg="WAL checkpoint loaded"
# ts=2023-03-21T17:24:36.825Z caller=head.go:685 level=info component=tsdb msg="WAL segment loaded" segment=33 maxSegment=36
# ts=2023-03-21T17:24:36.827Z caller=head.go:685 level=info component=tsdb msg="WAL segment loaded" segment=34 maxSegment=36
# ts=2023-03-21T17:24:36.831Z caller=head.go:685 level=info component=tsdb msg="WAL segment loaded" segment=35 maxSegment=36
# ts=2023-03-21T17:24:36.831Z caller=head.go:685 level=info component=tsdb msg="WAL segment loaded" segment=36 maxSegment=36
# ts=2023-03-21T17:24:36.831Z caller=head.go:722 level=info component=tsdb msg="WAL replay completed" checkpoint_replay_duration=41.014891ms wal_replay_duration=20.386332ms wbl_replay_duration=210ns total_replay_duration=61.416603ms
# ts=2023-03-21T17:24:36.857Z caller=main.go:1014 level=info fs_type=bd00bd0
# ts=2023-03-21T17:24:36.857Z caller=main.go:1017 level=info msg="TSDB started"
# ts=2023-03-21T17:24:36.857Z caller=main.go:1197 level=info msg="Loading configuration file" filename=/tmp/ray/session_latest/metrics/prometheus/prometheus.yml
# ts=2023-03-21T17:24:36.884Z caller=main.go:1234 level=info msg="Completed loading of configuration file" filename=/tmp/ray/session_latest/metrics/prometheus/prometheus.yml totalDuration=26.5009ms db_storage=891ns remote_storage=1.623µs web_handler=320ns query_engine=942ns scrape=26.279784ms scrape_sd=21.592µs notify=901ns notify_sd=1.884µs rules=1.243µs tracing=6.873µs
# ts=2023-03-21T17:24:36.884Z caller=main.go:978 level=info msg="Server is ready to receive web requests."
# ts=2023-03-21T17:24:36.884Z caller=manager.go:974 level=info component="rule manager" msg="Starting rule manager..."
# logger=settings t=2023-03-21T10:24:37.33127446-07:00 level=info msg="Starting Grafana" version=9.4.3 commit=cf0a135595 branch=HEAD compiled=2023-03-02T12:28:42-08:00
# logger=settings t=2023-03-21T10:24:37.331477482-07:00 level=warn msg="\"sentry\" frontend logging provider is deprecated and will be removed in the next major version. Use \"grafana\" provider instead."
# logger=settings t=2023-03-21T10:24:37.331494475-07:00 level=info msg="Config loaded from" file=/usr/share/grafana/conf/defaults.ini
# logger=settings t=2023-03-21T10:24:37.331498232-07:00 level=info msg="Config loaded from" file=/tmp/ray/session_latest/metrics/grafana/grafana.ini
# logger=settings t=2023-03-21T10:24:37.331501408-07:00 level=info msg="Config overridden from command line" arg="default.paths.data=/grafana"
# logger=settings t=2023-03-21T10:24:37.331503853-07:00 level=info msg="Config overridden from command line" arg="default.paths.logs=/var/log/grafana"
# logger=settings t=2023-03-21T10:24:37.331506398-07:00 level=info msg="Config overridden from command line" arg="default.paths.plugins=/grafana/plugins"
# logger=settings t=2023-03-21T10:24:37.331508903-07:00 level=info msg="Config overridden from command line" arg="default.paths.provisioning=/tmp/ray/session_latest/metrics/grafana/provisioning"
# logger=settings t=2023-03-21T10:24:37.331511648-07:00 level=info msg="Config overridden from command line" arg="default.log.mode=console"
# logger=settings t=2023-03-21T10:24:37.331514153-07:00 level=info msg="Config overridden from Environment variable" var="GF_PATHS_DATA=/grafana"
# logger=settings t=2023-03-21T10:24:37.331516558-07:00 level=info msg="Config overridden from Environment variable" var="GF_PATHS_LOGS=/var/log/grafana"
# logger=settings t=2023-03-21T10:24:37.331519072-07:00 level=info msg="Config overridden from Environment variable" var="GF_PATHS_PLUGINS=/grafana/plugins"
# logger=settings t=2023-03-21T10:24:37.331521467-07:00 level=info msg="Config overridden from Environment variable" var="GF_PATHS_PROVISIONING=/tmp/ray/session_latest/metrics/grafana/provisioning"
# logger=settings t=2023-03-21T10:24:37.331523801-07:00 level=info msg="Config overridden from Environment variable" var="GF_SERVER_ROOT_URL=https://jupyter.nersc.gov/user/asnaylor/perlmutter-shared-node-cpu/proxy/3000/"
# logger=settings t=2023-03-21T10:24:37.331526246-07:00 level=info msg="Path Home" path=/usr/share/grafana
# logger=settings t=2023-03-21T10:24:37.331528621-07:00 level=info msg="Path Data" path=/grafana
# logger=settings t=2023-03-21T10:24:37.331530785-07:00 level=info msg="Path Logs" path=/var/log/grafana
# logger=settings t=2023-03-21T10:24:37.33153337-07:00 level=info msg="Path Plugins" path=/grafana/plugins
# logger=settings t=2023-03-21T10:24:37.331536005-07:00 level=info msg="Path Provisioning" path=/tmp/ray/session_latest/metrics/grafana/provisioning
# logger=settings t=2023-03-21T10:24:37.33153863-07:00 level=info msg="App mode production"
# logger=sqlstore t=2023-03-21T10:24:37.331604838-07:00 level=info msg="Connecting to DB" dbtype=sqlite3
# logger=migrator t=2023-03-21T10:24:37.353412364-07:00 level=info msg="Starting DB migrations"
# logger=migrator t=2023-03-21T10:24:37.358272059-07:00 level=info msg="migrations completed" performed=0 skipped=481 duration=307.334µs
# logger=plugin.finder t=2023-03-21T10:24:37.405934019-07:00 level=warn msg="Skipping finding plugins as directory does not exist" path=/usr/share/grafana/plugins-bundled
# logger=secrets t=2023-03-21T10:24:37.407027039-07:00 level=info msg="Envelope encryption state" enabled=true currentprovider=secretKey.v1
# logger=query_data t=2023-03-21T10:24:37.410451433-07:00 level=info msg="Query Service initialization"
# logger=live.push_http t=2023-03-21T10:24:37.417877564-07:00 level=info msg="Live Push Gateway initialization"
# logger=infra.usagestats.collector t=2023-03-21T10:24:38.106722425-07:00 level=info msg="registering usage stat providers" usageStatsProvidersLen=2
# logger=provisioning.plugins t=2023-03-21T10:24:38.200175088-07:00 level=error msg="Failed to read plugin provisioning files from directory" path=/tmp/ray/session_latest/metrics/grafana/provisioning/plugins error="open /tmp/ray/session_latest/metrics/grafana/provisioning/plugins: no such file or directory"
# logger=provisioning.notifiers t=2023-03-21T10:24:38.200197221-07:00 level=error msg="Can't read alert notification provisioning files from directory" path=/tmp/ray/session_latest/metrics/grafana/provisioning/notifiers error="open /tmp/ray/session_latest/metrics/grafana/provisioning/notifiers: no such file or directory"
# logger=provisioning.alerting t=2023-03-21T10:24:38.200211689-07:00 level=error msg="can't read alerting provisioning files from directory" path=/tmp/ray/session_latest/metrics/grafana/provisioning/alerting error="open /tmp/ray/session_latest/metrics/grafana/provisioning/alerting: no such file or directory"
# logger=provisioning.alerting t=2023-03-21T10:24:38.200215677-07:00 level=info msg="starting to provision alerting"
# logger=provisioning.alerting t=2023-03-21T10:24:38.200221808-07:00 level=info msg="finished to provision alerting"
# logger=grafanaStorageLogger t=2023-03-21T10:24:38.200380054-07:00 level=info msg="storage starting"
# logger=ngalert.state.manager t=2023-03-21T10:24:38.200746662-07:00 level=info msg="Warming state cache for startup"
# logger=http.server t=2023-03-21T10:24:38.20803602-07:00 level=info msg="HTTP Server Listen" address=[::]:3000 protocol=http subUrl=/user/asnaylor/perlmutter-shared-node-cpu/proxy/3000 socket=
# logger=ngalert.state.manager t=2023-03-21T10:24:38.216484967-07:00 level=info msg="State cache has been initialized" states=0 duration=15.736953ms
# logger=ngalert.multiorg.alertmanager t=2023-03-21T10:24:38.216592805-07:00 level=info msg="starting MultiOrg Alertmanager"
# logger=ticker t=2023-03-21T10:24:38.219156597-07:00 level=info msg=starting first_tick=2023-03-21T10:24:40-07:00
# [slurm] - Starting 2 Ray worker nodes
#     - 1 at nid001361
#     - 2 at nid001364
# ts=2023-03-21T17:24:47.475Z caller=compact.go:510 level=info component=tsdb msg="write block resulted in empty block" mint=1678852800000 maxt=1678860000000 duration=12.510371ms
# ts=2023-03-21T17:24:47.477Z caller=head.go:1219 level=info component=tsdb msg="Head GC completed" caller=truncateMemory duration=610.468µs
# ts=2023-03-21T17:24:47.514Z caller=compact.go:519 level=info component=tsdb msg="write block" mint=1678914772657 maxt=1678917600000 ulid=01GW2K7D7N84Y5BFNS54MD50SM duration=37.337438ms
# ts=2023-03-21T17:24:47.518Z caller=head.go:1219 level=info component=tsdb msg="Head GC completed" caller=truncateMemory duration=1.04551ms
# ts=2023-03-21T17:24:47.518Z caller=checkpoint.go:100 level=info component=tsdb msg="Creating checkpoint" from_segment=33 to_segment=34 mint=1678917600000
# ts=2023-03-21T17:24:47.549Z caller=head.go:1191 level=info component=tsdb msg="WAL checkpoint complete" first=33 last=34 duration=31.538399ms
# [2023-03-21 10:24:56,193 I 126033 126033] global_state_accessor.cc:356: This node has an IP address of 128.55.66.67, while we can not find the matched Raylet address. This maybe come from when you connect the Ray cluster with a different IP address or connect a container.
# 2023-03-21 10:24:56,037	INFO scripts.py:866 -- Local node IP: 128.55.66.67
# 2023-03-21 10:24:56,194	SUCC scripts.py:878 -- --------------------
# 2023-03-21 10:24:56,195	SUCC scripts.py:879 -- Ray runtime started.
# 2023-03-21 10:24:56,195	SUCC scripts.py:880 -- --------------------
# 2023-03-21 10:24:56,195	INFO scripts.py:882 -- To terminate the Ray runtime, run
# 2023-03-21 10:24:56,195	INFO scripts.py:883 --   ray stop
# 2023-03-21 10:24:56,195	INFO scripts.py:888 -- --block
# 2023-03-21 10:24:56,195	INFO scripts.py:889 -- This command will now block forever until terminated by a signal.
# 2023-03-21 10:24:56,195	INFO scripts.py:892 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# [2023-03-21 10:24:59,247 I 92967 92967] global_state_accessor.cc:356: This node has an IP address of 128.55.67.168, while we can not find the matched Raylet address. This maybe come from when you connect the Ray cluster with a different IP address or connect a container.
# 2023-03-21 10:24:59,098	INFO scripts.py:866 -- Local node IP: 128.55.67.168
# 2023-03-21 10:24:59,248	SUCC scripts.py:878 -- --------------------
# 2023-03-21 10:24:59,248	SUCC scripts.py:879 -- Ray runtime started.
# 2023-03-21 10:24:59,248	SUCC scripts.py:880 -- --------------------
# 2023-03-21 10:24:59,249	INFO scripts.py:882 -- To terminate the Ray runtime, run
# 2023-03-21 10:24:59,249	INFO scripts.py:883 --   ray stop
# 2023-03-21 10:24:59,249	INFO scripts.py:888 -- --block
# 2023-03-21 10:24:59,249	INFO scripts.py:889 -- This command will now block forever until terminated by a signal.
# 2023-03-21 10:24:59,249	INFO scripts.py:892 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.

# %% [markdown]
# ## Connect to Ray + Grafana dashboards
#
# Port forward both dashboards and get the URL paths

# %%
from nersc_cluster_deploy import connect_ray_dashboard


ray_dashboard_url, grafana_dashboard_url = connect_ray_dashboard(
    sfp_api,
    job['jobid'],
    site
)

# %%
ray_dashboard_url
# Out:
# 'https://jupyter.nersc.gov/user/asnaylor/perlmutter-shared-node-cpu/proxy/localhost:8265/#/new/overview'

# %%
grafana_dashboard_url
# Out:
# 'https://jupyter.nersc.gov/user/asnaylor/perlmutter-shared-node-cpu/proxy/3000/d/rayDefaultDashboard'

# %% [markdown]
# ## Connect to Ray Cluster
#
# Get the Ray cluster head node ip address to connect to the cluster

# %%
from nersc_cluster_deploy import get_ray_cluster_address
import ray

cluster_address = get_ray_cluster_address(
    sfp_api,
    job['jobid'],
    site
)
ray.init(cluster_address)
# Out:
# ClientContext(dashboard_url='127.0.0.1:8265', python_version='3.9.15', ray_version='2.3.0', ray_commit='cf7a56b4b0b648c324722df7c99c168e92ff0b45', protocol_version='2022-12-06', _num_clients=1, _context_to_restore=<ray.util.client._ClientContext object at 0x14a129d49ca0>)

# %% [markdown]
# Check all nodes connected to cluster

# %%
from nersc_cluster_deploy import ray_cluster_summary

ray_cluster_summary()
# Out:
# Cluster Summary
# ---------------
# Nodes: 3
# CPU:   318
# GPU:   12
# RAM:   465.96 GB

# %% [markdown]
# ## Setup PyTorch Model

# %%
import argparse
import os

import torch
import torch.nn as nn
import torchvision.transforms as transforms
from filelock import FileLock
from torch.utils.data import DataLoader, Subset
from torchvision.datasets import CIFAR10
from torchvision.models import resnet18

import ray
import ray.train as train
from ray import tune
from ray.air import session
from ray.air.checkpoint import Checkpoint
from ray.air.config import FailureConfig, RunConfig, ScalingConfig
from ray.train.torch import TorchTrainer
from ray.tune.schedulers import PopulationBasedTraining
from ray.tune.tune_config import TuneConfig
from ray.tune.tuner import Tuner

# %%
def train_epoch(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset) // session.get_world_size()
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")


def validate_epoch(dataloader, model, loss_fn):
    size = len(dataloader.dataset) // session.get_world_size()
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(
        f"Test Error: \n "
        f"Accuracy: {(100 * correct):>0.1f}%, "
        f"Avg loss: {test_loss:>8f} \n"
    )
    return {"loss": test_loss}


def update_optimizer_config(optimizer, config):
    for param_group in optimizer.param_groups:
        for param, val in config.items():
            param_group[param] = val


def train_func(config):
    epochs = config.get("epochs", 3)

    model = resnet18()

    # Note that `prepare_model` needs to be called before setting optimizer.
    if not session.get_checkpoint():  # fresh start
        model = train.torch.prepare_model(model)

    # Create optimizer.
    optimizer_config = {
        "lr": config.get("lr"),
        "momentum": config.get("momentum"),
    }
    optimizer = torch.optim.SGD(model.parameters(), **optimizer_config)

    starting_epoch = 0
    if session.get_checkpoint():
        checkpoint_dict = session.get_checkpoint().to_dict()

        # Load in model
        model_state = checkpoint_dict["model"]
        model.load_state_dict(model_state)
        model = train.torch.prepare_model(model)

        # Load in optimizer
        optimizer_state = checkpoint_dict["optimizer_state_dict"]
        optimizer.load_state_dict(optimizer_state)

        # Optimizer configs (`lr`, `momentum`) are being mutated by PBT and passed in
        # through config, so we need to update the optimizer loaded from the checkpoint
        update_optimizer_config(optimizer, optimizer_config)

        # The current epoch increments the loaded epoch by 1
        checkpoint_epoch = checkpoint_dict["epoch"]
        starting_epoch = checkpoint_epoch + 1

    # Load in training and validation data.
    transform_train = transforms.Compose(
        [
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
        ]
    )  # meanstd transformation

    transform_test = transforms.Compose(
        [
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
        ]
    )

    data_dir = config.get("data_dir", os.path.expanduser("~/data"))
    os.makedirs(data_dir, exist_ok=True)
    with FileLock(os.path.join(data_dir, ".ray.lock")):
        train_dataset = CIFAR10(
            root=data_dir, train=True, download=True, transform=transform_train
        )
        validation_dataset = CIFAR10(
            root=data_dir, train=False, download=False, transform=transform_test
        )

    if config.get("test_mode"):
        train_dataset = Subset(train_dataset, list(range(64)))
        validation_dataset = Subset(validation_dataset, list(range(64)))

    worker_batch_size = config["batch_size"] // session.get_world_size()

    train_loader = DataLoader(train_dataset, batch_size=worker_batch_size)
    validation_loader = DataLoader(validation_dataset, batch_size=worker_batch_size)

    train_loader = train.torch.prepare_data_loader(train_loader)
    validation_loader = train.torch.prepare_data_loader(validation_loader)

    # Create loss.
    criterion = nn.CrossEntropyLoss()

    for epoch in range(starting_epoch, epochs):
        train_epoch(train_loader, model, criterion, optimizer)
        result = validate_epoch(validation_loader, model, criterion)
        checkpoint = Checkpoint.from_dict(
            {
                "epoch": epoch,
                "model": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
            }
        )

        session.report(result, checkpoint=checkpoint)

# %% [markdown]
# ## Train Model

# %%
SCRATCH = os.getenv('SCRATCH')

node_resources = ray.cluster_resources()
num_workers = int(node_resources['GPU'])
use_gpu = True

data_dir = os.path.join(SCRATCH, 'CIFAR10')
num_epochs = 5
smoke_test = False
synch = False

# %%
trainer = TorchTrainer(
        train_func,
        scaling_config=ScalingConfig(
            num_workers=num_workers, use_gpu=use_gpu
        ),
    )

# %%
pbt_scheduler = PopulationBasedTraining(
        time_attr="training_iteration",
        perturbation_interval=1,
        hyperparam_mutations={
            "train_loop_config": {
                # distribution for resampling
                "lr": tune.loguniform(0.001, 0.1),
                # allow perturbations within this set of categorical values
                "momentum": [0.8, 0.9, 0.99],
            }
        },
        synch=synch,
    )

# %%
tuner = Tuner(
        trainer,
        param_space={
            "train_loop_config": {
                "lr": tune.grid_search([0.001, 0.01, 0.05, 0.1]),
                "momentum": 0.8,
                "batch_size": 128 * num_workers,
                "test_mode": smoke_test,  # whether to to subset the data
                "data_dir": data_dir,
                "epochs": num_epochs,
            }
        },
        tune_config=TuneConfig(
            num_samples=1, metric="loss", mode="min", scheduler=pbt_scheduler
        ),
        run_config=RunConfig(
            stop={"training_iteration": 3 if smoke_test else num_epochs},
            failure_config=FailureConfig(max_failures=3),  # used for fault tolerance
        ),
    )

# %%
results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-03-21 10:36:24</td></tr>
# <tr><td>Running for: </td><td>00:09:49.22        </td></tr>
# <tr><td>Memory:      </td><td>51.1/251.3 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       PopulationBasedTraining: 7 checkpoints, 2 perturbs<br>Resources requested: 0/318 CPUs, 0/12 GPUs, 0.0/465.96 GiB heap, 0.0/203.69 GiB objects (0.0/3.0 accelerator_type:A100)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name              </th><th>status    </th><th>loc              </th><th style="text-align: right;">  train_loop_config/lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   loss</th><th style="text-align: right;">  _timestamp</th><th style="text-align: right;">  _time_this_iter_s</th></tr>
# </thead>
# <tbody>
# <tr><td>TorchTrainer_876a2_00000</td><td>TERMINATED</td><td>128.55.66.67:7315</td><td style="text-align: right;">                 0.06 </td><td style="text-align: right;">     5</td><td style="text-align: right;">         117.741</td><td style="text-align: right;">1.20098</td><td style="text-align: right;">  1679420097</td><td style="text-align: right;">            19.068 </td></tr>
# <tr><td>TorchTrainer_876a2_00001</td><td>TERMINATED</td><td>128.55.66.67:8132</td><td style="text-align: right;">                 0.01 </td><td style="text-align: right;">     5</td><td style="text-align: right;">         120.926</td><td style="text-align: right;">1.32064</td><td style="text-align: right;">  1679420126</td><td style="text-align: right;">            18.9816</td></tr>
# <tr><td>TorchTrainer_876a2_00002</td><td>TERMINATED</td><td>pid=16032        </td><td style="text-align: right;">                 0.05 </td><td style="text-align: right;">     5</td><td style="text-align: right;">         118.06 </td><td style="text-align: right;">1.1953 </td><td style="text-align: right;">  1679420156</td><td style="text-align: right;">            19.0394</td></tr>
# <tr><td>TorchTrainer_876a2_00003</td><td>TERMINATED</td><td>pid=17557        </td><td style="text-align: right;">                 0.048</td><td style="text-align: right;">     5</td><td style="text-align: right;">         117.507</td><td style="text-align: right;">1.14191</td><td style="text-align: right;">  1679420184</td><td style="text-align: right;">            19.2617</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (TunerInternal pid=125486) /global/homes/a/asnaylor/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/ray/tune/tune.py:562: UserWarning: Consider boosting PBT performance by enabling `reuse_actors` as well as implementing `reset_config` for Trainable.
# (TunerInternal pid=125486)   warnings.warn(
# (TunerInternal pid=125486) 2023-03-21 10:26:35,092	WARNING trial_runner.py:369 -- The maximum number of pending trials has been automatically set to the number of available cluster CPUs, which is high (349 CPUs/pending trials). If you're running an experiment with a large number of trials, this could lead to scheduling overhead. In this case, consider setting the `TUNE_MAX_PENDING_TRIALS_PG` environment variable to the desired maximum number of concurrent trials.
# (TunerInternal pid=125486) 2023-03-21 10:26:35,095	WARNING trial_runner.py:1677 -- You are trying to access _search_alg interface of TrialRunner in TrialScheduler, which is being restricted. If you believe it is reasonable for your scheduler to access this TrialRunner API, please reach out to Ray team on GitHub. A more strict API access pattern would be enforced starting 1.12s.0
# (RayTrainWorker pid=126806, ip=128.55.66.67) 2023-03-21 10:26:46,542	INFO config.py:86 -- Setting up process group for: env:// [rank=0, world_size=12]
# (RayTrainWorker pid=126806, ip=128.55.66.67) 2023-03-21 10:26:48,612	INFO train_loop_utils.py:255 -- Moving model to device: cuda:3
# (RayTrainWorker pid=125989) 2023-03-21 10:26:48,586	INFO train_loop_utils.py:255 -- Moving model to device: cuda:3
# (RayTrainWorker pid=93576, ip=128.55.67.168) 2023-03-21 10:26:48,607	INFO train_loop_utils.py:255 -- Moving model to device: cuda:3
# (RayTrainWorker pid=126806, ip=128.55.66.67) 2023-03-21 10:26:50,690	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=93576, ip=128.55.67.168) 2023-03-21 10:26:50,930	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=125989) 2023-03-21 10:26:51,138	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=126806, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=126807, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=126808, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=126809, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=93576, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=93579, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=93578, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=93577, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=125989) Files already downloaded and verified
# (RayTrainWorker pid=125990) Files already downloaded and verified
# (RayTrainWorker pid=125992) Files already downloaded and verified
# (RayTrainWorker pid=125991) Files already downloaded and verified
# (RayTrainWorker pid=93578, ip=128.55.67.168) loss: 6.940266  [    0/ 4166]
# (RayTrainWorker pid=93577, ip=128.55.67.168) loss: 7.106786  [    0/ 4166]
# (RayTrainWorker pid=93576, ip=128.55.67.168) loss: 7.017751  [    0/ 4166]
# (RayTrainWorker pid=93579, ip=128.55.67.168) loss: 7.005786  [    0/ 4166]
# (RayTrainWorker pid=125990) loss: 7.089641  [    0/ 4166]
# (RayTrainWorker pid=125991) loss: 7.053966  [    0/ 4166]
# (RayTrainWorker pid=125992) loss: 7.145356  [    0/ 4166]
# (RayTrainWorker pid=125989) loss: 7.151267  [    0/ 4166]
# (RayTrainWorker pid=126809, ip=128.55.66.67) loss: 7.077059  [    0/ 4166]
# (RayTrainWorker pid=126808, ip=128.55.66.67) loss: 7.043056  [    0/ 4166]
# (RayTrainWorker pid=126807, ip=128.55.66.67) loss: 6.960145  [    0/ 4166]
# (RayTrainWorker pid=126806, ip=128.55.66.67) loss: 7.121526  [    0/ 4166]
# (RayTrainWorker pid=126809, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=126809, ip=128.55.66.67)  Accuracy: 21.6%, Avg loss: 3.674793
# (RayTrainWorker pid=126809, ip=128.55.66.67)
# (RayTrainWorker pid=126808, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=126808, ip=128.55.66.67)  Accuracy: 21.2%, Avg loss: 3.675970
# (RayTrainWorker pid=126808, ip=128.55.66.67)
# (RayTrainWorker pid=126807, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=126807, ip=128.55.66.67)  Accuracy: 21.4%, Avg loss: 3.693226
# (RayTrainWorker pid=126807, ip=128.55.66.67)
# (RayTrainWorker pid=126806, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=126806, ip=128.55.66.67)  Accuracy: 22.1%, Avg loss: 3.678907
# (RayTrainWorker pid=126806, ip=128.55.66.67)
# (RayTrainWorker pid=93578, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=93578, ip=128.55.67.168)  Accuracy: 18.8%, Avg loss: 3.702728
# (RayTrainWorker pid=93578, ip=128.55.67.168)
# (RayTrainWorker pid=93577, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=93577, ip=128.55.67.168)  Accuracy: 22.9%, Avg loss: 3.637997
# (RayTrainWorker pid=93577, ip=128.55.67.168)
# (RayTrainWorker pid=93576, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=93576, ip=128.55.67.168)  Accuracy: 19.9%, Avg loss: 3.658186
# (RayTrainWorker pid=93576, ip=128.55.67.168)
# (RayTrainWorker pid=93579, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=93579, ip=128.55.67.168)  Accuracy: 19.8%, Avg loss: 3.696000
# (RayTrainWorker pid=93579, ip=128.55.67.168)
# (RayTrainWorker pid=125990) Test Error:
# (RayTrainWorker pid=125990)  Accuracy: 21.7%, Avg loss: 3.674891
# (RayTrainWorker pid=125990)
# (RayTrainWorker pid=125991) Test Error:
# (RayTrainWorker pid=125991)  Accuracy: 21.4%, Avg loss: 3.687669
# (RayTrainWorker pid=125991)
# (RayTrainWorker pid=125992) Test Error:
# (RayTrainWorker pid=125992)  Accuracy: 21.2%, Avg loss: 3.664541
# (RayTrainWorker pid=125992)
# (RayTrainWorker pid=125989) Test Error:
# (RayTrainWorker pid=125989)  Accuracy: 22.6%, Avg loss: 3.666127
# (RayTrainWorker pid=125989)
# (TunerInternal pid=125486) Result for TorchTrainer_876a2_00000:
# (TunerInternal pid=125486)   _time_this_iter_s: 19.958574056625366
# (TunerInternal pid=125486)   _timestamp: 1679419628
# (TunerInternal pid=125486)   _training_iteration: 1
# (TunerInternal pid=125486)   date: 2023-03-21_10-27-08
# (TunerInternal pid=125486)   done: false
# (TunerInternal pid=125486)   experiment_id: 53278e032fae459da159b97d261f2e68
# (TunerInternal pid=125486)   hostname: nid001361
# (TunerInternal pid=125486)   iterations_since_restore: 1
# (TunerInternal pid=125486)   loss: 3.6789066791534424
# (TunerInternal pid=125486)   node_ip: 128.55.66.67
# (TunerInternal pid=125486)   pid: 126645
# (TunerInternal pid=125486)   should_checkpoint: true
# (TunerInternal pid=125486)   time_since_restore: 25.868615865707397
# (TunerInternal pid=125486)   time_this_iter_s: 25.868615865707397
# (TunerInternal pid=125486)   time_total_s: 25.868615865707397
# (TunerInternal pid=125486)   timestamp: 1679419628
# (TunerInternal pid=125486)   timesteps_since_restore: 0
# (TunerInternal pid=125486)   training_iteration: 1
# (TunerInternal pid=125486)   trial_id: 876a2_00000
# (TunerInternal pid=125486)   warmup_time: 0.5166716575622559
# (TunerInternal pid=125486)
# (RayTrainWorker pid=125990) loss: 2.881926  [    0/ 4166]
# (RayTrainWorker pid=125991) loss: 3.031126  [    0/ 4166]
# (RayTrainWorker pid=125992) loss: 2.994125  [    0/ 4166]
# (RayTrainWorker pid=125989) loss: 2.996607  [    0/ 4166]
# (RayTrainWorker pid=126809, ip=128.55.66.67) loss: 2.923560  [    0/ 4166]
# (RayTrainWorker pid=126808, ip=128.55.66.67) loss: 2.918392  [    0/ 4166]
# (RayTrainWorker pid=126807, ip=128.55.66.67) loss: 2.832437  [    0/ 4166]
# (RayTrainWorker pid=126806, ip=128.55.66.67) loss: 2.924379  [    0/ 4166]
# (RayTrainWorker pid=93578, ip=128.55.67.168) loss: 2.872632  [    0/ 4166]
# (RayTrainWorker pid=93577, ip=128.55.67.168) loss: 2.961953  [    0/ 4166]
# (RayTrainWorker pid=93576, ip=128.55.67.168) loss: 2.862138  [    0/ 4166]
# (RayTrainWorker pid=93579, ip=128.55.67.168) loss: 2.971265  [    0/ 4166]
# (RayTrainWorker pid=93578, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=93578, ip=128.55.67.168)  Accuracy: 28.2%, Avg loss: 2.216320
# (RayTrainWorker pid=93578, ip=128.55.67.168)
# (RayTrainWorker pid=93577, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=93577, ip=128.55.67.168)  Accuracy: 28.3%, Avg loss: 2.120290
# (RayTrainWorker pid=93577, ip=128.55.67.168)
# (RayTrainWorker pid=93576, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=93576, ip=128.55.67.168)  Accuracy: 26.3%, Avg loss: 2.145903
# (RayTrainWorker pid=93576, ip=128.55.67.168)
# (RayTrainWorker pid=93579, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=93579, ip=128.55.67.168)  Accuracy: 28.5%, Avg loss: 2.168828
# (RayTrainWorker pid=93579, ip=128.55.67.168)
# (RayTrainWorker pid=125990) Test Error:
# (RayTrainWorker pid=125990)  Accuracy: 25.8%, Avg loss: 2.170428
# (RayTrainWorker pid=125990)
# (RayTrainWorker pid=125991) Test Error:
# (RayTrainWorker pid=125991)  Accuracy: 27.9%, Avg loss: 2.174198
# (RayTrainWorker pid=125991)
# (RayTrainWorker pid=125992) Test Error:
# (RayTrainWorker pid=125992)  Accuracy: 28.0%, Avg loss: 2.153603
# (RayTrainWorker pid=125992)
# (RayTrainWorker pid=125989) Test Error:
# (RayTrainWorker pid=125989)  Accuracy: 29.9%, Avg loss: 2.151351
# (RayTrainWorker pid=125989)
# (RayTrainWorker pid=126809, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=126809, ip=128.55.66.67)  Accuracy: 28.9%, Avg loss: 2.168020
# (RayTrainWorker pid=126809, ip=128.55.66.67)
# (RayTrainWorker pid=126808, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=126808, ip=128.55.66.67)  Accuracy: 28.0%, Avg loss: 2.169938
# (RayTrainWorker pid=126808, ip=128.55.66.67)
# (RayTrainWorker pid=126807, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=126807, ip=128.55.66.67)  Accuracy: 25.8%, Avg loss: 2.166167
# (RayTrainWorker pid=126807, ip=128.55.66.67)
# (RayTrainWorker pid=126806, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=126806, ip=128.55.66.67)  Accuracy: 26.3%, Avg loss: 2.226340
# (RayTrainWorker pid=126806, ip=128.55.66.67)
# (RayTrainWorker pid=127168) 2023-03-21 10:27:17,174	INFO config.py:86 -- Setting up process group for: env:// [rank=0, world_size=12]
# (RayTrainWorker pid=127821, ip=128.55.66.67) 2023-03-21 10:27:18,989	INFO train_loop_utils.py:255 -- Moving model to device: cuda:2
# (RayTrainWorker pid=94097, ip=128.55.67.168) 2023-03-21 10:27:19,019	INFO train_loop_utils.py:255 -- Moving model to device: cuda:2
# (RayTrainWorker pid=127168) 2023-03-21 10:27:19,005	INFO train_loop_utils.py:255 -- Moving model to device: cuda:2
# (RayTrainWorker pid=127821, ip=128.55.66.67) 2023-03-21 10:27:20,501	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=94097, ip=128.55.67.168) 2023-03-21 10:27:20,591	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=127168) 2023-03-21 10:27:20,741	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=127171) Files already downloaded and verified
# (RayTrainWorker pid=127170) Files already downloaded and verified
# (RayTrainWorker pid=127821, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=127823, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=127169) Files already downloaded and verified
# (RayTrainWorker pid=127168) Files already downloaded and verified
# (RayTrainWorker pid=94098, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=94097, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=127824, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=127822, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=94099, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=94100, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=127170) loss: 6.900143  [    0/ 4166]
# (RayTrainWorker pid=127171) loss: 7.147995  [    0/ 4166]
# (RayTrainWorker pid=127169) loss: 6.969028  [    0/ 4166]
# (RayTrainWorker pid=127168) loss: 7.105084  [    0/ 4166]
# (RayTrainWorker pid=127822, ip=128.55.66.67) loss: 7.007416  [    0/ 4166]
# (RayTrainWorker pid=127821, ip=128.55.66.67) loss: 7.139005  [    0/ 4166]
# (RayTrainWorker pid=127823, ip=128.55.66.67) loss: 6.966797  [    0/ 4166]
# (RayTrainWorker pid=127824, ip=128.55.66.67) loss: 7.021337  [    0/ 4166]
# (RayTrainWorker pid=94100, ip=128.55.67.168) loss: 7.104116  [    0/ 4166]
# (RayTrainWorker pid=94099, ip=128.55.67.168) loss: 6.932979  [    0/ 4166]
# (RayTrainWorker pid=94098, ip=128.55.67.168) loss: 7.003395  [    0/ 4166]
# (RayTrainWorker pid=94097, ip=128.55.67.168) loss: 7.053316  [    0/ 4166]
# (RayTrainWorker pid=94100, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=94100, ip=128.55.67.168)  Accuracy: 37.0%, Avg loss: 1.687550
# (RayTrainWorker pid=94100, ip=128.55.67.168)
# (RayTrainWorker pid=94099, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=94099, ip=128.55.67.168)  Accuracy: 34.1%, Avg loss: 1.786143
# (RayTrainWorker pid=94099, ip=128.55.67.168)
# (RayTrainWorker pid=94098, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=94098, ip=128.55.67.168)  Accuracy: 36.3%, Avg loss: 1.746377
# (RayTrainWorker pid=94098, ip=128.55.67.168)
# (RayTrainWorker pid=94097, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=94097, ip=128.55.67.168)  Accuracy: 39.4%, Avg loss: 1.733385
# (RayTrainWorker pid=94097, ip=128.55.67.168)
# (RayTrainWorker pid=127170) Test Error:
# (RayTrainWorker pid=127170)  Accuracy: 36.7%, Avg loss: 1.747572
# (RayTrainWorker pid=127170)
# (RayTrainWorker pid=127171) Test Error:
# (RayTrainWorker pid=127171)  Accuracy: 39.4%, Avg loss: 1.724387
# (RayTrainWorker pid=127171)
# (RayTrainWorker pid=127169) Test Error:
# (RayTrainWorker pid=127169)  Accuracy: 35.5%, Avg loss: 1.770207
# (RayTrainWorker pid=127169)
# (RayTrainWorker pid=127168) Test Error:
# (RayTrainWorker pid=127168)  Accuracy: 35.8%, Avg loss: 1.795658
# (RayTrainWorker pid=127168)
# (RayTrainWorker pid=127822, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=127822, ip=128.55.66.67)  Accuracy: 39.4%, Avg loss: 1.702786
# (RayTrainWorker pid=127822, ip=128.55.66.67)
# (RayTrainWorker pid=127821, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=127821, ip=128.55.66.67)  Accuracy: 39.3%, Avg loss: 1.707966
# (RayTrainWorker pid=127821, ip=128.55.66.67)
# (RayTrainWorker pid=127823, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=127823, ip=128.55.66.67)  Accuracy: 34.1%, Avg loss: 1.734073
# (RayTrainWorker pid=127823, ip=128.55.66.67)
# (RayTrainWorker pid=127824, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=127824, ip=128.55.66.67)  Accuracy: 31.6%, Avg loss: 1.799246
# (RayTrainWorker pid=127824, ip=128.55.66.67)
# (TunerInternal pid=125486) Result for TorchTrainer_876a2_00001:
# (TunerInternal pid=125486)   _time_this_iter_s: 17.554426431655884
# (TunerInternal pid=125486)   _timestamp: 1679419656
# (TunerInternal pid=125486)   _training_iteration: 1
# (TunerInternal pid=125486)   date: 2023-03-21_10-27-38
# (TunerInternal pid=125486)   done: false
# (TunerInternal pid=125486)   experiment_id: 9d661d9aa5f84d2b85801ba09a0f46bc
# (TunerInternal pid=125486)   hostname: nid001164
# (TunerInternal pid=125486)   iterations_since_restore: 1
# (TunerInternal pid=125486)   loss: 1.7956575155258179
# (TunerInternal pid=125486)   node_ip: nid001164
# (TunerInternal pid=125486)   pid: 127026
# (TunerInternal pid=125486)   should_checkpoint: true
# (TunerInternal pid=125486)   time_since_restore: 23.511271953582764
# (TunerInternal pid=125486)   time_this_iter_s: 23.511271953582764
# (TunerInternal pid=125486)   time_total_s: 23.511271953582764
# (TunerInternal pid=125486)   timestamp: 1679419658
# (TunerInternal pid=125486)   timesteps_since_restore: 0
# (TunerInternal pid=125486)   training_iteration: 1
# (TunerInternal pid=125486)   trial_id: 876a2_00001
# (TunerInternal pid=125486)   warmup_time: 0.18092560768127441
# (TunerInternal pid=125486)
# (RayTrainWorker pid=127170) loss: 1.673169  [    0/ 4166]
# (RayTrainWorker pid=127171) loss: 1.751243  [    0/ 4166]
# (RayTrainWorker pid=127169) loss: 1.753339  [    0/ 4166]
# (RayTrainWorker pid=127168) loss: 1.633661  [    0/ 4166]
# (RayTrainWorker pid=127822, ip=128.55.66.67) loss: 1.678177  [    0/ 4166]
# (RayTrainWorker pid=127821, ip=128.55.66.67) loss: 1.756411  [    0/ 4166]
# (RayTrainWorker pid=127823, ip=128.55.66.67) loss: 1.784995  [    0/ 4166]
# (RayTrainWorker pid=127824, ip=128.55.66.67) loss: 1.746183  [    0/ 4166]
# (RayTrainWorker pid=94100, ip=128.55.67.168) loss: 1.824914  [    0/ 4166]
# (RayTrainWorker pid=94099, ip=128.55.67.168) loss: 1.845170  [    0/ 4166]
# (RayTrainWorker pid=94098, ip=128.55.67.168) loss: 1.892562  [    0/ 4166]
# (RayTrainWorker pid=94097, ip=128.55.67.168) loss: 1.821994  [    0/ 4166]
# (RayTrainWorker pid=128269) 2023-03-21 10:27:44,281	INFO config.py:86 -- Setting up process group for: env:// [rank=0, world_size=12]
# (RayTrainWorker pid=128313, ip=128.55.66.67) 2023-03-21 10:27:46,099	INFO train_loop_utils.py:255 -- Moving model to device: cuda:2
# (RayTrainWorker pid=128269) 2023-03-21 10:27:46,063	INFO train_loop_utils.py:255 -- Moving model to device: cuda:2
# (RayTrainWorker pid=94589, ip=128.55.67.168) 2023-03-21 10:27:46,092	INFO train_loop_utils.py:255 -- Moving model to device: cuda:2
# (RayTrainWorker pid=94589, ip=128.55.67.168) 2023-03-21 10:27:47,610	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=128269) 2023-03-21 10:27:47,646	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=128313, ip=128.55.66.67) 2023-03-21 10:27:47,721	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=94592, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=94589, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=94590, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=94591, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=128272) Files already downloaded and verified
# (RayTrainWorker pid=128314, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=128315, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=128316, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=128271) Files already downloaded and verified
# (RayTrainWorker pid=128269) Files already downloaded and verified
# (RayTrainWorker pid=128270) Files already downloaded and verified
# (RayTrainWorker pid=128313, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=128314, ip=128.55.66.67) loss: 7.306346  [    0/ 4166]
# (RayTrainWorker pid=128313, ip=128.55.66.67) loss: 7.303646  [    0/ 4166]
# (RayTrainWorker pid=128315, ip=128.55.66.67) loss: 7.310593  [    0/ 4166]
# (RayTrainWorker pid=128316, ip=128.55.66.67) loss: 7.226707  [    0/ 4166]
# (RayTrainWorker pid=94591, ip=128.55.67.168) loss: 7.189660  [    0/ 4166]
# (RayTrainWorker pid=94592, ip=128.55.67.168) loss: 7.391003  [    0/ 4166]
# (RayTrainWorker pid=94590, ip=128.55.67.168) loss: 7.139311  [    0/ 4166]
# (RayTrainWorker pid=94589, ip=128.55.67.168) loss: 7.238660  [    0/ 4166]
# (RayTrainWorker pid=128272) loss: 7.323067  [    0/ 4166]
# (RayTrainWorker pid=128270) loss: 7.256296  [    0/ 4166]
# (RayTrainWorker pid=128271) loss: 7.358472  [    0/ 4166]
# (RayTrainWorker pid=128269) loss: 7.295964  [    0/ 4166]
# (RayTrainWorker pid=128314, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=128314, ip=128.55.66.67)  Accuracy: 42.7%, Avg loss: 1.562025
# (RayTrainWorker pid=128314, ip=128.55.66.67)
# (RayTrainWorker pid=128313, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=128313, ip=128.55.66.67)  Accuracy: 44.3%, Avg loss: 1.528560
# (RayTrainWorker pid=128313, ip=128.55.66.67)
# (RayTrainWorker pid=128315, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=128315, ip=128.55.66.67)  Accuracy: 42.5%, Avg loss: 1.576918
# (RayTrainWorker pid=128315, ip=128.55.66.67)
# (RayTrainWorker pid=128316, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=128316, ip=128.55.66.67)  Accuracy: 42.5%, Avg loss: 1.571787
# (RayTrainWorker pid=128316, ip=128.55.66.67)
# (RayTrainWorker pid=94591, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=94591, ip=128.55.67.168)  Accuracy: 43.8%, Avg loss: 1.555033
# (RayTrainWorker pid=94591, ip=128.55.67.168)
# (RayTrainWorker pid=94592, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=94592, ip=128.55.67.168)  Accuracy: 45.4%, Avg loss: 1.516947
# (RayTrainWorker pid=94592, ip=128.55.67.168)
# (RayTrainWorker pid=94590, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=94590, ip=128.55.67.168)  Accuracy: 45.9%, Avg loss: 1.542739
# (RayTrainWorker pid=94590, ip=128.55.67.168)
# (RayTrainWorker pid=94589, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=94589, ip=128.55.67.168)  Accuracy: 43.1%, Avg loss: 1.515738
# (RayTrainWorker pid=94589, ip=128.55.67.168)
# (RayTrainWorker pid=128272) Test Error:
# (RayTrainWorker pid=128272)  Accuracy: 42.6%, Avg loss: 1.555840
# (RayTrainWorker pid=128272)
# (RayTrainWorker pid=128270) Test Error:
# (RayTrainWorker pid=128270)  Accuracy: 40.6%, Avg loss: 1.588232
# (RayTrainWorker pid=128270)
# (RayTrainWorker pid=128271) Test Error:
# (RayTrainWorker pid=128271)  Accuracy: 47.2%, Avg loss: 1.520556
# (RayTrainWorker pid=128271)
# (RayTrainWorker pid=128269) Test Error:
# (RayTrainWorker pid=128269)  Accuracy: 42.4%, Avg loss: 1.572477
# (RayTrainWorker pid=128269)
# (RayTrainWorker pid=128314, ip=128.55.66.67) loss: 1.506325  [    0/ 4166]
# (RayTrainWorker pid=128313, ip=128.55.66.67) loss: 1.604909  [    0/ 4166]
# (RayTrainWorker pid=128315, ip=128.55.66.67) loss: 1.562698  [    0/ 4166]
# (RayTrainWorker pid=128316, ip=128.55.66.67) loss: 1.739794  [    0/ 4166]
# (RayTrainWorker pid=94591, ip=128.55.67.168) loss: 1.684293  [    0/ 4166]
# (RayTrainWorker pid=94592, ip=128.55.67.168) loss: 1.472163  [    0/ 4166]
# (RayTrainWorker pid=94590, ip=128.55.67.168) loss: 1.605361  [    0/ 4166]
# (RayTrainWorker pid=94589, ip=128.55.67.168) loss: 1.710595  [    0/ 4166]
# (TunerInternal pid=125486) Result for TorchTrainer_876a2_00002:
# (TunerInternal pid=125486)   _time_this_iter_s: 17.269100189208984
# (TunerInternal pid=125486)   _timestamp: 1679419683
# (TunerInternal pid=125486)   _training_iteration: 1
# (TunerInternal pid=125486)   date: 2023-03-21_10-28-03
# (TunerInternal pid=125486)   done: false
# (TunerInternal pid=125486)   experiment_id: 2f564592309a4b05aee19a4ec9d1a599
# (TunerInternal pid=125486)   hostname: nid001164
# (TunerInternal pid=125486)   iterations_since_restore: 1
# (TunerInternal pid=125486)   loss: 1.5724770511899675
# (TunerInternal pid=125486)   node_ip: nid001164
# (TunerInternal pid=125486)   pid: 128121
# (TunerInternal pid=125486)   should_checkpoint: true
# (TunerInternal pid=125486)   time_since_restore: 21.938036918640137
# (TunerInternal pid=125486)   time_this_iter_s: 21.938036918640137
# (TunerInternal pid=125486)   time_total_s: 21.938036918640137
# (TunerInternal pid=125486)   timestamp: 1679419683
# (TunerInternal pid=125486)   timesteps_since_restore: 0
# (TunerInternal pid=125486)   training_iteration: 1
# (TunerInternal pid=125486)   trial_id: 876a2_00002
# (TunerInternal pid=125486)   warmup_time: 0.17292356491088867
# (TunerInternal pid=125486)
# (RayTrainWorker pid=128272) loss: 1.567229  [    0/ 4166]
# (RayTrainWorker pid=128270) loss: 1.632727  [    0/ 4166]
# (RayTrainWorker pid=128271) loss: 1.637259  [    0/ 4166]
# (RayTrainWorker pid=128269) loss: 1.501052  [    0/ 4166]
# (RayTrainWorker pid=128939, ip=128.55.66.67) 2023-03-21 10:28:09,090	INFO config.py:86 -- Setting up process group for: env:// [rank=0, world_size=12]
# (RayTrainWorker pid=95110, ip=128.55.67.168) 2023-03-21 10:28:11,016	INFO train_loop_utils.py:255 -- Moving model to device: cuda:1
# (RayTrainWorker pid=128939, ip=128.55.66.67) 2023-03-21 10:28:11,021	INFO train_loop_utils.py:255 -- Moving model to device: cuda:1
# (RayTrainWorker pid=129203) 2023-03-21 10:28:11,026	INFO train_loop_utils.py:255 -- Moving model to device: cuda:1
# (RayTrainWorker pid=129203) 2023-03-21 10:28:12,519	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=95110, ip=128.55.67.168) 2023-03-21 10:28:12,609	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=128939, ip=128.55.66.67) 2023-03-21 10:28:12,581	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=128939, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=129205) Files already downloaded and verified
# (RayTrainWorker pid=129206) Files already downloaded and verified
# (RayTrainWorker pid=95110, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=95112, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=95111, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=129204) Files already downloaded and verified
# (RayTrainWorker pid=129203) Files already downloaded and verified
# (RayTrainWorker pid=128942, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=128941, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=128940, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=95113, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=129206) loss: 7.050045  [    0/ 4166]
# (RayTrainWorker pid=129205) loss: 7.083547  [    0/ 4166]
# (RayTrainWorker pid=129204) loss: 7.047108  [    0/ 4166]
# (RayTrainWorker pid=129203) loss: 7.136214  [    0/ 4166]
# (RayTrainWorker pid=95112, ip=128.55.67.168) loss: 7.014990  [    0/ 4166]
# (RayTrainWorker pid=95113, ip=128.55.67.168) loss: 7.121753  [    0/ 4166]
# (RayTrainWorker pid=95111, ip=128.55.67.168) loss: 7.015991  [    0/ 4166]
# (RayTrainWorker pid=95110, ip=128.55.67.168) loss: 7.043484  [    0/ 4166]
# (RayTrainWorker pid=128942, ip=128.55.66.67) loss: 7.146814  [    0/ 4166]
# (RayTrainWorker pid=128941, ip=128.55.66.67) loss: 7.015175  [    0/ 4166]
# (RayTrainWorker pid=128940, ip=128.55.66.67) loss: 7.057657  [    0/ 4166]
# (RayTrainWorker pid=128939, ip=128.55.66.67) loss: 7.069033  [    0/ 4166]
# (RayTrainWorker pid=95112, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=95112, ip=128.55.67.168)  Accuracy: 30.7%, Avg loss: 1.953366
# (RayTrainWorker pid=95112, ip=128.55.67.168)
# (RayTrainWorker pid=95113, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=95113, ip=128.55.67.168)  Accuracy: 29.8%, Avg loss: 1.976868
# (RayTrainWorker pid=95113, ip=128.55.67.168)
# (RayTrainWorker pid=95111, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=95111, ip=128.55.67.168)  Accuracy: 30.9%, Avg loss: 1.910316
# (RayTrainWorker pid=95111, ip=128.55.67.168)
# (RayTrainWorker pid=95110, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=95110, ip=128.55.67.168)  Accuracy: 32.4%, Avg loss: 1.908204
# (RayTrainWorker pid=95110, ip=128.55.67.168)
# (RayTrainWorker pid=128942, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=128942, ip=128.55.66.67)  Accuracy: 30.5%, Avg loss: 1.959874
# (RayTrainWorker pid=128942, ip=128.55.66.67)
# (RayTrainWorker pid=128941, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=128941, ip=128.55.66.67)  Accuracy: 27.7%, Avg loss: 2.008046
# (RayTrainWorker pid=128941, ip=128.55.66.67)
# (RayTrainWorker pid=128940, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=128940, ip=128.55.66.67)  Accuracy: 29.7%, Avg loss: 1.958414
# (RayTrainWorker pid=128940, ip=128.55.66.67)
# (RayTrainWorker pid=128939, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=128939, ip=128.55.66.67)  Accuracy: 30.3%, Avg loss: 1.998552
# (RayTrainWorker pid=128939, ip=128.55.66.67)
# (RayTrainWorker pid=129206) Test Error:
# (RayTrainWorker pid=129206)  Accuracy: 28.1%, Avg loss: 2.005244
# (RayTrainWorker pid=129206)
# (RayTrainWorker pid=129205) Test Error:
# (RayTrainWorker pid=129205)  Accuracy: 29.3%, Avg loss: 1.928023
# (RayTrainWorker pid=129205)
# (RayTrainWorker pid=129204) Test Error:
# (RayTrainWorker pid=129204)  Accuracy: 30.5%, Avg loss: 1.958009
# (RayTrainWorker pid=129204)
# (RayTrainWorker pid=129203) Test Error:
# (RayTrainWorker pid=129203)  Accuracy: 31.1%, Avg loss: 1.931940
# (RayTrainWorker pid=129203)
# (TunerInternal pid=125486) Result for TorchTrainer_876a2_00003:
# (TunerInternal pid=125486)   _time_this_iter_s: 17.325608491897583
# (TunerInternal pid=125486)   _timestamp: 1679419708
# (TunerInternal pid=125486)   _training_iteration: 1
# (TunerInternal pid=125486)   date: 2023-03-21_10-28-28
# (TunerInternal pid=125486)   done: false
# (TunerInternal pid=125486)   experiment_id: fdcc74443faf410997f018944b736ffa
# (TunerInternal pid=125486)   hostname: nid001361
# (TunerInternal pid=125486)   iterations_since_restore: 1
# (TunerInternal pid=125486)   loss: 1.998551641191755
# (TunerInternal pid=125486)   node_ip: 128.55.66.67
# (TunerInternal pid=125486)   pid: 128833
# (TunerInternal pid=125486)   should_checkpoint: true
# (TunerInternal pid=125486)   time_since_restore: 21.84858274459839
# (TunerInternal pid=125486)   time_this_iter_s: 21.84858274459839
# (TunerInternal pid=125486)   time_total_s: 21.84858274459839
# (TunerInternal pid=125486)   timestamp: 1679419708
# (TunerInternal pid=125486)   timesteps_since_restore: 0
# (TunerInternal pid=125486)   training_iteration: 1
# (TunerInternal pid=125486)   trial_id: 876a2_00003
# (TunerInternal pid=125486)   warmup_time: 0.1598498821258545
# (TunerInternal pid=125486)
# (RayTrainWorker pid=129206) loss: 2.017981  [    0/ 4166]
# (RayTrainWorker pid=129205) loss: 1.812854  [    0/ 4166]
# (RayTrainWorker pid=129204) loss: 1.778604  [    0/ 4166]
# (RayTrainWorker pid=129203) loss: 1.862213  [    0/ 4166]
# (RayTrainWorker pid=95112, ip=128.55.67.168) loss: 1.804641  [    0/ 4166]
# (RayTrainWorker pid=95113, ip=128.55.67.168) loss: 1.842174  [    0/ 4166]
# (RayTrainWorker pid=95111, ip=128.55.67.168) loss: 1.879239  [    0/ 4166]
# (RayTrainWorker pid=95110, ip=128.55.67.168) loss: 1.647811  [    0/ 4166]
# (RayTrainWorker pid=128942, ip=128.55.66.67) loss: 1.820485  [    0/ 4166]
# (RayTrainWorker pid=128941, ip=128.55.66.67) loss: 1.732838  [    0/ 4166]
# (RayTrainWorker pid=128940, ip=128.55.66.67) loss: 1.838373  [    0/ 4166]
# (RayTrainWorker pid=128939, ip=128.55.66.67) loss: 1.607955  [    0/ 4166]
# (RayTrainWorker pid=128942, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=128942, ip=128.55.66.67)  Accuracy: 47.3%, Avg loss: 1.442905
# (RayTrainWorker pid=128942, ip=128.55.66.67)
# (RayTrainWorker pid=128941, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=128941, ip=128.55.66.67)  Accuracy: 45.0%, Avg loss: 1.492899
# (RayTrainWorker pid=128941, ip=128.55.66.67)
# (RayTrainWorker pid=128940, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=128940, ip=128.55.66.67)  Accuracy: 45.1%, Avg loss: 1.537000
# (RayTrainWorker pid=128940, ip=128.55.66.67)
# (RayTrainWorker pid=128939, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=128939, ip=128.55.66.67)  Accuracy: 46.3%, Avg loss: 1.542220
# (RayTrainWorker pid=128939, ip=128.55.66.67)
# (RayTrainWorker pid=129206) Test Error:
# (RayTrainWorker pid=129206)  Accuracy: 45.0%, Avg loss: 1.520916
# (RayTrainWorker pid=129206)
# (RayTrainWorker pid=129205) Test Error:
# (RayTrainWorker pid=129205)  Accuracy: 46.9%, Avg loss: 1.431736
# (RayTrainWorker pid=129205)
# (RayTrainWorker pid=129204) Test Error:
# (RayTrainWorker pid=129204)  Accuracy: 45.1%, Avg loss: 1.525063
# (RayTrainWorker pid=129204)
# (RayTrainWorker pid=129203) Test Error:
# (RayTrainWorker pid=129203)  Accuracy: 46.9%, Avg loss: 1.487530
# (RayTrainWorker pid=129203)
# (RayTrainWorker pid=95112, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=95112, ip=128.55.67.168)  Accuracy: 46.5%, Avg loss: 1.463350
# (RayTrainWorker pid=95112, ip=128.55.67.168)
# (RayTrainWorker pid=95113, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=95113, ip=128.55.67.168)  Accuracy: 40.8%, Avg loss: 1.554685
# (RayTrainWorker pid=95113, ip=128.55.67.168)
# (RayTrainWorker pid=95111, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=95111, ip=128.55.67.168)  Accuracy: 45.3%, Avg loss: 1.470988
# (RayTrainWorker pid=95111, ip=128.55.67.168)
# (RayTrainWorker pid=95110, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=95110, ip=128.55.67.168)  Accuracy: 46.5%, Avg loss: 1.475000
# (RayTrainWorker pid=95110, ip=128.55.67.168)
# (TunerInternal pid=125486) 2023-03-21 10:28:30,399	WARNING util.py:244 -- The `process_trial_save` operation took 2.029 s, which may be a performance bottleneck.
# (TunerInternal pid=125486) 2023-03-21 10:28:30,399	WARNING trial_runner.py:1033 -- Consider turning off forced head-worker trial checkpoint syncs by setting sync_on_checkpoint=False. Note that this may result in faulty trial restoration if a failure occurs while the checkpoint is being synced from the worker to the head node.
# (TorchTrainer pid=129630, ip=128.55.66.67) 2023-03-21 10:28:33,750	INFO trainable.py:791 -- Restored on 128.55.66.67 from checkpoint: /global/homes/a/asnaylor/ray_results/TorchTrainer_2023-03-21_10-26-33/TorchTrainer_876a2_00000_0_lr=0.0010_2023-03-21_10-26-35/checkpoint_tmp0f7a48
# (TorchTrainer pid=129630, ip=128.55.66.67) 2023-03-21 10:28:33,750	INFO trainable.py:800 -- Current state after restoring: {'_iteration': 1, '_timesteps_total': None, '_time_total': 25.868615865707397, '_episodes_total': None}
# (RayTrainWorker pid=129760, ip=128.55.66.67) 2023-03-21 10:28:36,266	INFO config.py:86 -- Setting up process group for: env:// [rank=0, world_size=12]
# (RayTrainWorker pid=130215) 2023-03-21 10:28:40,372	INFO train_loop_utils.py:255 -- Moving model to device: cuda:3
# (RayTrainWorker pid=95603, ip=128.55.67.168) 2023-03-21 10:28:40,361	INFO train_loop_utils.py:255 -- Moving model to device: cuda:3
# (RayTrainWorker pid=129760, ip=128.55.66.67) 2023-03-21 10:28:40,334	INFO train_loop_utils.py:255 -- Moving model to device: cuda:3
# (RayTrainWorker pid=129760, ip=128.55.66.67) 2023-03-21 10:28:41,889	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=95603, ip=128.55.67.168) 2023-03-21 10:28:41,934	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=130215) 2023-03-21 10:28:41,962	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=129760, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=130218) Files already downloaded and verified
# (RayTrainWorker pid=130216) Files already downloaded and verified
# (RayTrainWorker pid=130217) Files already downloaded and verified
# (RayTrainWorker pid=95604, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=95603, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=95606, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=95605, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=129761, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=129763, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=129762, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=130215) Files already downloaded and verified
# (RayTrainWorker pid=130215) loss: 2.904722  [    0/ 4166]
# (RayTrainWorker pid=130217) loss: 2.984762  [    0/ 4166]
# (RayTrainWorker pid=130218) loss: 2.927933  [    0/ 4166]
# (RayTrainWorker pid=130216) loss: 2.947577  [    0/ 4166]
# (RayTrainWorker pid=129763, ip=128.55.66.67) loss: 2.956465  [    0/ 4166]
# (RayTrainWorker pid=129762, ip=128.55.66.67) loss: 2.894697  [    0/ 4166]
# (RayTrainWorker pid=129761, ip=128.55.66.67) loss: 2.952363  [    0/ 4166]
# (RayTrainWorker pid=129760, ip=128.55.66.67) loss: 2.879951  [    0/ 4166]
# (RayTrainWorker pid=95604, ip=128.55.67.168) loss: 2.922616  [    0/ 4166]
# (RayTrainWorker pid=95603, ip=128.55.67.168) loss: 2.790132  [    0/ 4166]
# (RayTrainWorker pid=95605, ip=128.55.67.168) loss: 2.930533  [    0/ 4166]
# (RayTrainWorker pid=95606, ip=128.55.67.168) loss: 2.965958  [    0/ 4166]
# (RayTrainWorker pid=130215) Test Error:
# (RayTrainWorker pid=130215)  Accuracy: 28.1%, Avg loss: 2.162798
# (RayTrainWorker pid=130215)
# (RayTrainWorker pid=130217) Test Error:
# (RayTrainWorker pid=130217)  Accuracy: 25.9%, Avg loss: 2.200263
# (RayTrainWorker pid=130217)
# (RayTrainWorker pid=130218) Test Error:
# (RayTrainWorker pid=130218)  Accuracy: 28.0%, Avg loss: 2.136532
# (RayTrainWorker pid=130218)
# (RayTrainWorker pid=130216) Test Error:
# (RayTrainWorker pid=130216)  Accuracy: 24.5%, Avg loss: 2.164682
# (RayTrainWorker pid=130216)
# (RayTrainWorker pid=129763, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=129763, ip=128.55.66.67)  Accuracy: 27.0%, Avg loss: 2.195786
# (RayTrainWorker pid=129763, ip=128.55.66.67)
# (RayTrainWorker pid=129762, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=129762, ip=128.55.66.67)  Accuracy: 27.0%, Avg loss: 2.170888
# (RayTrainWorker pid=129762, ip=128.55.66.67)
# (RayTrainWorker pid=129761, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=129761, ip=128.55.66.67)  Accuracy: 25.2%, Avg loss: 2.170419
# (RayTrainWorker pid=129761, ip=128.55.66.67)
# (RayTrainWorker pid=129760, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=129760, ip=128.55.66.67)  Accuracy: 26.7%, Avg loss: 2.224115
# (RayTrainWorker pid=129760, ip=128.55.66.67)
# (RayTrainWorker pid=95604, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=95604, ip=128.55.67.168)  Accuracy: 28.9%, Avg loss: 2.124125
# (RayTrainWorker pid=95604, ip=128.55.67.168)
# (RayTrainWorker pid=95603, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=95603, ip=128.55.67.168)  Accuracy: 25.5%, Avg loss: 2.149294
# (RayTrainWorker pid=95603, ip=128.55.67.168)
# (RayTrainWorker pid=95605, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=95605, ip=128.55.67.168)  Accuracy: 28.1%, Avg loss: 2.210738
# (RayTrainWorker pid=95605, ip=128.55.67.168)
# (RayTrainWorker pid=95606, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=95606, ip=128.55.67.168)  Accuracy: 26.2%, Avg loss: 2.184326
# (RayTrainWorker pid=95606, ip=128.55.67.168)
# (TunerInternal pid=125486) 2023-03-21 10:28:57,510	INFO pbt.py:804 --
# (TunerInternal pid=125486)
# (TunerInternal pid=125486) [PopulationBasedTraining] [Exploit] Cloning trial 876a2_00002 (score = -1.572477) into trial 876a2_00000 (score = -2.224115)
# (TunerInternal pid=125486)
# (TunerInternal pid=125486) 2023-03-21 10:28:57,510	INFO pbt.py:831 --
# (TunerInternal pid=125486)
# (TunerInternal pid=125486) [PopulationBasedTraining] [Explore] Perturbed the hyperparameter config of trial876a2_00000:
# (TunerInternal pid=125486) train_loop_config :
# (TunerInternal pid=125486)     lr : 0.05 --- (* 1.2) --> 0.06
# (TunerInternal pid=125486)     momentum : 0.8 --- (resample) --> 0.8
# (TunerInternal pid=125486)
# (TunerInternal pid=125486) Result for TorchTrainer_876a2_00000:
# (TunerInternal pid=125486)   _time_this_iter_s: 19.077677965164185
# (TunerInternal pid=125486)   _timestamp: 1679419737
# (TunerInternal pid=125486)   _training_iteration: 1
# (TunerInternal pid=125486)   date: 2023-03-21_10-28-57
# (TunerInternal pid=125486)   done: false
# (TunerInternal pid=125486)   experiment_id: 53278e032fae459da159b97d261f2e68
# (TunerInternal pid=125486)   hostname: nid001361
# (TunerInternal pid=125486)   iterations_since_restore: 1
# (TunerInternal pid=125486)   loss: 2.2241149629865373
# (TunerInternal pid=125486)   node_ip: 128.55.66.67
# (TunerInternal pid=125486)   pid: 129630
# (TunerInternal pid=125486)   should_checkpoint: true
# (TunerInternal pid=125486)   time_since_restore: 23.756930112838745
# (TunerInternal pid=125486)   time_this_iter_s: 23.756930112838745
# (TunerInternal pid=125486)   time_total_s: 49.62554597854614
# (TunerInternal pid=125486)   timestamp: 1679419737
# (TunerInternal pid=125486)   timesteps_since_restore: 0
# (TunerInternal pid=125486)   training_iteration: 2
# (TunerInternal pid=125486)   trial_id: 876a2_00000
# (TunerInternal pid=125486)   warmup_time: 0.4088096618652344
# (TunerInternal pid=125486)
# (TorchTrainer pid=578) 2023-03-21 10:29:00,647	INFO trainable.py:791 -- Restored on nid001164 from checkpoint: /global/homes/a/asnaylor/ray_results/TorchTrainer_2023-03-21_10-26-33/TorchTrainer_876a2_00000_0_lr=0.0010_2023-03-21_10-26-35/checkpoint_tmp2a9b55
# (TorchTrainer pid=578) 2023-03-21 10:29:00,647	INFO trainable.py:800 -- Current state after restoring: {'_iteration': 1, '_timesteps_total': None, '_time_total': 21.938036918640137, '_episodes_total': None}
# (RayTrainWorker pid=957) 2023-03-21 10:29:03,227	INFO config.py:86 -- Setting up process group for: env:// [rank=0, world_size=12]
# (RayTrainWorker pid=96149, ip=128.55.67.168) 2023-03-21 10:29:07,316	INFO train_loop_utils.py:255 -- Moving model to device: cuda:3
# (RayTrainWorker pid=957) 2023-03-21 10:29:07,296	INFO train_loop_utils.py:255 -- Moving model to device: cuda:3
# (RayTrainWorker pid=130262, ip=128.55.66.67) 2023-03-21 10:29:07,324	INFO train_loop_utils.py:255 -- Moving model to device: cuda:3
# (RayTrainWorker pid=96149, ip=128.55.67.168) 2023-03-21 10:29:08,798	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=957) 2023-03-21 10:29:08,837	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=130262, ip=128.55.66.67) 2023-03-21 10:29:08,922	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=957) Files already downloaded and verified
# (RayTrainWorker pid=959) Files already downloaded and verified
# (RayTrainWorker pid=960) Files already downloaded and verified
# (RayTrainWorker pid=958) Files already downloaded and verified
# (RayTrainWorker pid=130264, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=130263, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=130262, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=130265, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=96149, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=96151, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=96150, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=96152, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=130265, ip=128.55.66.67) loss: 1.692790  [    0/ 4166]
# (RayTrainWorker pid=130264, ip=128.55.66.67) loss: 1.626002  [    0/ 4166]
# (RayTrainWorker pid=130263, ip=128.55.66.67) loss: 1.600802  [    0/ 4166]
# (RayTrainWorker pid=130262, ip=128.55.66.67) loss: 1.626026  [    0/ 4166]
# (RayTrainWorker pid=96152, ip=128.55.67.168) loss: 1.535123  [    0/ 4166]
# (RayTrainWorker pid=96151, ip=128.55.67.168) loss: 1.657123  [    0/ 4166]
# (RayTrainWorker pid=96150, ip=128.55.67.168) loss: 1.581240  [    0/ 4166]
# (RayTrainWorker pid=96149, ip=128.55.67.168) loss: 1.767556  [    0/ 4166]
# (RayTrainWorker pid=957) loss: 1.504488  [    0/ 4166]
# (RayTrainWorker pid=960) loss: 1.553509  [    0/ 4166]
# (RayTrainWorker pid=958) loss: 1.672768  [    0/ 4166]
# (RayTrainWorker pid=959) loss: 1.616307  [    0/ 4166]
# (RayTrainWorker pid=130265, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=130265, ip=128.55.66.67)  Accuracy: 48.3%, Avg loss: 1.449337
# (RayTrainWorker pid=130265, ip=128.55.66.67)
# (RayTrainWorker pid=130264, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=130264, ip=128.55.66.67)  Accuracy: 46.5%, Avg loss: 1.449342
# (RayTrainWorker pid=130264, ip=128.55.66.67)
# (RayTrainWorker pid=130263, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=130263, ip=128.55.66.67)  Accuracy: 47.9%, Avg loss: 1.427227
# (RayTrainWorker pid=130263, ip=128.55.66.67)
# (RayTrainWorker pid=130262, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=130262, ip=128.55.66.67)  Accuracy: 52.3%, Avg loss: 1.402595
# (RayTrainWorker pid=130262, ip=128.55.66.67)
# (RayTrainWorker pid=96152, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=96152, ip=128.55.67.168)  Accuracy: 50.3%, Avg loss: 1.345079
# (RayTrainWorker pid=96152, ip=128.55.67.168)
# (RayTrainWorker pid=96151, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=96151, ip=128.55.67.168)  Accuracy: 46.6%, Avg loss: 1.474177
# (RayTrainWorker pid=96151, ip=128.55.67.168)
# (RayTrainWorker pid=96150, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=96150, ip=128.55.67.168)  Accuracy: 47.9%, Avg loss: 1.439245
# (RayTrainWorker pid=96150, ip=128.55.67.168)
# ...
# (RayTrainWorker pid=102854, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=8240, ip=128.55.66.67) loss: 1.537392  [    0/ 4166]
# (RayTrainWorker pid=8239, ip=128.55.66.67) loss: 1.374896  [    0/ 4166]
# (RayTrainWorker pid=8238, ip=128.55.66.67) loss: 1.449666  [    0/ 4166]
# (RayTrainWorker pid=8237, ip=128.55.66.67) loss: 1.277300  [    0/ 4166]
# (RayTrainWorker pid=102853, ip=128.55.67.168) loss: 1.346246  [    0/ 4166]
# (RayTrainWorker pid=102854, ip=128.55.67.168) loss: 1.454143  [    0/ 4166]
# (RayTrainWorker pid=102852, ip=128.55.67.168) loss: 1.424859  [    0/ 4166]
# (RayTrainWorker pid=102851, ip=128.55.67.168) loss: 1.377026  [    0/ 4166]
# (RayTrainWorker pid=15089) loss: 1.401304  [    0/ 4166]
# (RayTrainWorker pid=15088) loss: 1.422891  [    0/ 4166]
# (RayTrainWorker pid=15086) loss: 1.318500  [    0/ 4166]
# (RayTrainWorker pid=15084) loss: 1.471013  [    0/ 4166]
# (RayTrainWorker pid=8240, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=8240, ip=128.55.66.67)  Accuracy: 54.9%, Avg loss: 1.259346
# (RayTrainWorker pid=8240, ip=128.55.66.67)
# (RayTrainWorker pid=8239, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=8239, ip=128.55.66.67)  Accuracy: 52.7%, Avg loss: 1.289038
# (RayTrainWorker pid=8239, ip=128.55.66.67)
# (RayTrainWorker pid=8238, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=8238, ip=128.55.66.67)  Accuracy: 51.7%, Avg loss: 1.358520
# (RayTrainWorker pid=8238, ip=128.55.66.67)
# (RayTrainWorker pid=8237, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=8237, ip=128.55.66.67)  Accuracy: 53.1%, Avg loss: 1.320638
# (RayTrainWorker pid=8237, ip=128.55.66.67)
# (RayTrainWorker pid=102853, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=102853, ip=128.55.67.168)  Accuracy: 50.2%, Avg loss: 1.367697
# (RayTrainWorker pid=102853, ip=128.55.67.168)
# (RayTrainWorker pid=102854, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=102854, ip=128.55.67.168)  Accuracy: 53.1%, Avg loss: 1.292181
# (RayTrainWorker pid=102854, ip=128.55.67.168)
# (RayTrainWorker pid=102852, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=102852, ip=128.55.67.168)  Accuracy: 50.7%, Avg loss: 1.330547
# (RayTrainWorker pid=102852, ip=128.55.67.168)
# (RayTrainWorker pid=102851, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=102851, ip=128.55.67.168)  Accuracy: 52.0%, Avg loss: 1.303656
# (RayTrainWorker pid=102851, ip=128.55.67.168)
# (RayTrainWorker pid=15089) Test Error:
# (RayTrainWorker pid=15089)  Accuracy: 55.7%, Avg loss: 1.229728
# (RayTrainWorker pid=15089)
# (RayTrainWorker pid=15088) Test Error:
# (RayTrainWorker pid=15088)  Accuracy: 51.3%, Avg loss: 1.348369
# (RayTrainWorker pid=15088)
# (RayTrainWorker pid=15086) Test Error:
# (RayTrainWorker pid=15086)  Accuracy: 49.8%, Avg loss: 1.350880
# (RayTrainWorker pid=15086)
# (RayTrainWorker pid=15084) Test Error:
# (RayTrainWorker pid=15084)  Accuracy: 54.1%, Avg loss: 1.276799
# (RayTrainWorker pid=15084)
# (TunerInternal pid=125486) Result for TorchTrainer_876a2_00001:
# (TunerInternal pid=125486)   _time_this_iter_s: 18.981637954711914
# (TunerInternal pid=125486)   _timestamp: 1679420126
# (TunerInternal pid=125486)   _training_iteration: 1
# (TunerInternal pid=125486)   date: 2023-03-21_10-35-27
# (TunerInternal pid=125486)   done: true
# (TunerInternal pid=125486)   experiment_id: 9d661d9aa5f84d2b85801ba09a0f46bc
# (TunerInternal pid=125486)   hostname: nid001361
# (TunerInternal pid=125486)   iterations_since_restore: 1
# (TunerInternal pid=125486)   loss: 1.3206380946295602
# (TunerInternal pid=125486)   node_ip: 128.55.66.67
# (TunerInternal pid=125486)   pid: 8132
# (TunerInternal pid=125486)   should_checkpoint: true
# (TunerInternal pid=125486)   time_since_restore: 24.02269172668457
# (TunerInternal pid=125486)   time_this_iter_s: 24.02269172668457
# (TunerInternal pid=125486)   time_total_s: 120.9264349937439
# (TunerInternal pid=125486)   timestamp: 1679420127
# (TunerInternal pid=125486)   timesteps_since_restore: 0
# (TunerInternal pid=125486)   training_iteration: 5
# (TunerInternal pid=125486)   trial_id: 876a2_00001
# (TunerInternal pid=125486)   warmup_time: 0.31194257736206055
# (TunerInternal pid=125486)
# (TunerInternal pid=125486) Trial TorchTrainer_876a2_00001 completed.
# (TunerInternal pid=125486) 2023-03-21 10:35:28,214	WARNING util.py:244 -- The `process_trial_save` operation took 0.975 s, which may be a performance bottleneck.
# (TorchTrainer pid=16032) 2023-03-21 10:35:32,667	INFO trainable.py:791 -- Restored on nid001164 from checkpoint: /global/homes/a/asnaylor/ray_results/TorchTrainer_2023-03-21_10-26-33/TorchTrainer_876a2_00002_2_lr=0.0500_2023-03-21_10-27-38/checkpoint_tmpcc26c9
# (TorchTrainer pid=16032) 2023-03-21 10:35:32,667	INFO trainable.py:800 -- Current state after restoring: {'_iteration': 4, '_timesteps_total': None, '_time_total': 93.77648591995239, '_episodes_total': None}
# (RayTrainWorker pid=16180) 2023-03-21 10:35:35,764	INFO config.py:86 -- Setting up process group for: env:// [rank=0, world_size=12]
# (RayTrainWorker pid=8949, ip=128.55.66.67) 2023-03-21 10:35:39,778	INFO train_loop_utils.py:255 -- Moving model to device: cuda:0
# (RayTrainWorker pid=16180) 2023-03-21 10:35:39,808	INFO train_loop_utils.py:255 -- Moving model to device: cuda:0
# (RayTrainWorker pid=103368, ip=128.55.67.168) 2023-03-21 10:35:39,813	INFO train_loop_utils.py:255 -- Moving model to device: cuda:0
# (RayTrainWorker pid=103368, ip=128.55.67.168) 2023-03-21 10:35:41,327	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=8949, ip=128.55.66.67) 2023-03-21 10:35:41,327	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=16180) 2023-03-21 10:35:41,331	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=103369, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=103368, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=16183) Files already downloaded and verified
# (RayTrainWorker pid=16180) Files already downloaded and verified
# (RayTrainWorker pid=16182) Files already downloaded and verified
# (RayTrainWorker pid=16181) Files already downloaded and verified
# (RayTrainWorker pid=103370, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=103371, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=8951, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=8952, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=8949, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=8950, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=8952, ip=128.55.66.67) loss: 1.258440  [    0/ 4166]
# (RayTrainWorker pid=8950, ip=128.55.66.67) loss: 1.205386  [    0/ 4166]
# (RayTrainWorker pid=8949, ip=128.55.66.67) loss: 1.168532  [    0/ 4166]
# (RayTrainWorker pid=8951, ip=128.55.66.67) loss: 1.289157  [    0/ 4166]
# (RayTrainWorker pid=103370, ip=128.55.67.168) loss: 1.201172  [    0/ 4166]
# (RayTrainWorker pid=103369, ip=128.55.67.168) loss: 1.180443  [    0/ 4166]
# (RayTrainWorker pid=103368, ip=128.55.67.168) loss: 1.382005  [    0/ 4166]
# (RayTrainWorker pid=103371, ip=128.55.67.168) loss: 1.105978  [    0/ 4166]
# (RayTrainWorker pid=16183) loss: 1.313603  [    0/ 4166]
# (RayTrainWorker pid=16182) loss: 1.302353  [    0/ 4166]
# (RayTrainWorker pid=16181) loss: 1.230306  [    0/ 4166]
# (RayTrainWorker pid=16180) loss: 1.163895  [    0/ 4166]
# (RayTrainWorker pid=103370, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=103370, ip=128.55.67.168)  Accuracy: 59.1%, Avg loss: 1.153705
# (RayTrainWorker pid=103370, ip=128.55.67.168)
# (RayTrainWorker pid=103369, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=103369, ip=128.55.67.168)  Accuracy: 60.9%, Avg loss: 1.167616
# (RayTrainWorker pid=103369, ip=128.55.67.168)
# (RayTrainWorker pid=103368, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=103368, ip=128.55.67.168)  Accuracy: 58.2%, Avg loss: 1.156299
# (RayTrainWorker pid=103368, ip=128.55.67.168)
# (RayTrainWorker pid=103371, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=103371, ip=128.55.67.168)  Accuracy: 60.7%, Avg loss: 1.076962
# (RayTrainWorker pid=103371, ip=128.55.67.168)
# (RayTrainWorker pid=8952, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=8952, ip=128.55.66.67)  Accuracy: 61.0%, Avg loss: 1.138062
# (RayTrainWorker pid=8952, ip=128.55.66.67)
# (RayTrainWorker pid=8950, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=8950, ip=128.55.66.67)  Accuracy: 57.9%, Avg loss: 1.144059
# (RayTrainWorker pid=8950, ip=128.55.66.67)
# (RayTrainWorker pid=8949, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=8949, ip=128.55.66.67)  Accuracy: 60.4%, Avg loss: 1.160435
# (RayTrainWorker pid=8949, ip=128.55.66.67)
# (RayTrainWorker pid=8951, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=8951, ip=128.55.66.67)  Accuracy: 57.3%, Avg loss: 1.213832
# (RayTrainWorker pid=8951, ip=128.55.66.67)
# (RayTrainWorker pid=16183) Test Error:
# (RayTrainWorker pid=16183)  Accuracy: 62.4%, Avg loss: 1.078457
# (RayTrainWorker pid=16183)
# (RayTrainWorker pid=16182) Test Error:
# (RayTrainWorker pid=16182)  Accuracy: 59.7%, Avg loss: 1.146790
# (RayTrainWorker pid=16182)
# (RayTrainWorker pid=16181) Test Error:
# (RayTrainWorker pid=16181)  Accuracy: 58.6%, Avg loss: 1.167411
# (RayTrainWorker pid=16181)
# (RayTrainWorker pid=16180) Test Error:
# (RayTrainWorker pid=16180)  Accuracy: 60.0%, Avg loss: 1.195302
# (RayTrainWorker pid=16180)
# (TunerInternal pid=125486) Result for TorchTrainer_876a2_00002:
# (TunerInternal pid=125486)   _time_this_iter_s: 19.039371967315674
# (TunerInternal pid=125486)   _timestamp: 1679420156
# (TunerInternal pid=125486)   _training_iteration: 1
# (TunerInternal pid=125486)   date: 2023-03-21_10-35-56
# (TunerInternal pid=125486)   done: true
# (TunerInternal pid=125486)   experiment_id: 2f564592309a4b05aee19a4ec9d1a599
# (TunerInternal pid=125486)   hostname: nid001164
# (TunerInternal pid=125486)   iterations_since_restore: 1
# (TunerInternal pid=125486)   loss: 1.1953022820608956
# (TunerInternal pid=125486)   node_ip: nid001164
# (TunerInternal pid=125486)   pid: 16032
# (TunerInternal pid=125486)   should_checkpoint: true
# (TunerInternal pid=125486)   time_since_restore: 24.283587217330933
# (TunerInternal pid=125486)   time_this_iter_s: 24.283587217330933
# (TunerInternal pid=125486)   time_total_s: 118.06007313728333
# (TunerInternal pid=125486)   timestamp: 1679420156
# (TunerInternal pid=125486)   timesteps_since_restore: 0
# (TunerInternal pid=125486)   training_iteration: 5
# (TunerInternal pid=125486)   trial_id: 876a2_00002
# (TunerInternal pid=125486)   warmup_time: 0.3014564514160156
# (TunerInternal pid=125486)
# (TunerInternal pid=125486) Trial TorchTrainer_876a2_00002 completed.
# (TorchTrainer pid=17557) 2023-03-21 10:35:59,933	INFO trainable.py:791 -- Restored on nid001164 from checkpoint: /global/homes/a/asnaylor/ray_results/TorchTrainer_2023-03-21_10-26-33/TorchTrainer_876a2_00003_3_lr=0.1000_2023-03-21_10-28-03/checkpoint_tmpe4edea
# (TorchTrainer pid=17557) 2023-03-21 10:35:59,933	INFO trainable.py:800 -- Current state after restoring: {'_iteration': 4, '_timesteps_total': None, '_time_total': 93.14122271537781, '_episodes_total': None}
# (RayTrainWorker pid=17707) 2023-03-21 10:36:02,920	INFO config.py:86 -- Setting up process group for: env:// [rank=0, world_size=12]
# (RayTrainWorker pid=103865, ip=128.55.67.168) 2023-03-21 10:36:06,871	INFO train_loop_utils.py:255 -- Moving model to device: cuda:2
# (RayTrainWorker pid=17707) 2023-03-21 10:36:06,893	INFO train_loop_utils.py:255 -- Moving model to device: cuda:2
# (RayTrainWorker pid=9445, ip=128.55.66.67) 2023-03-21 10:36:06,894	INFO train_loop_utils.py:255 -- Moving model to device: cuda:2
# (RayTrainWorker pid=103865, ip=128.55.67.168) 2023-03-21 10:36:08,472	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=17707) 2023-03-21 10:36:08,542	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=9445, ip=128.55.66.67) 2023-03-21 10:36:08,572	INFO train_loop_utils.py:315 -- Wrapping provided model in DistributedDataParallel.
# (RayTrainWorker pid=103866, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=103868, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=9447, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=17708) Files already downloaded and verified
# (RayTrainWorker pid=9445, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=17710) Files already downloaded and verified
# (RayTrainWorker pid=17707) Files already downloaded and verified
# (RayTrainWorker pid=9446, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=9448, ip=128.55.66.67) Files already downloaded and verified
# (RayTrainWorker pid=103865, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=17709) Files already downloaded and verified
# (RayTrainWorker pid=103867, ip=128.55.67.168) Files already downloaded and verified
# (RayTrainWorker pid=9446, ip=128.55.66.67) loss: 1.201538  [    0/ 4166]
# (RayTrainWorker pid=9445, ip=128.55.66.67) loss: 1.200706  [    0/ 4166]
# (RayTrainWorker pid=9447, ip=128.55.66.67) loss: 1.221487  [    0/ 4166]
# (RayTrainWorker pid=9448, ip=128.55.66.67) loss: 1.299149  [    0/ 4166]
# (RayTrainWorker pid=103867, ip=128.55.67.168) loss: 1.307611  [    0/ 4166]
# (RayTrainWorker pid=103868, ip=128.55.67.168) loss: 1.098415  [    0/ 4166]
# (RayTrainWorker pid=103866, ip=128.55.67.168) loss: 1.244617  [    0/ 4166]
# (RayTrainWorker pid=103865, ip=128.55.67.168) loss: 1.285769  [    0/ 4166]
# (RayTrainWorker pid=17709) loss: 1.227383  [    0/ 4166]
# (RayTrainWorker pid=17710) loss: 1.250245  [    0/ 4166]
# (RayTrainWorker pid=17708) loss: 1.285904  [    0/ 4166]
# (RayTrainWorker pid=17707) loss: 1.225742  [    0/ 4166]
# (RayTrainWorker pid=103867, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=103867, ip=128.55.67.168)  Accuracy: 58.9%, Avg loss: 1.166549
# (RayTrainWorker pid=103867, ip=128.55.67.168)
# (RayTrainWorker pid=103868, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=103868, ip=128.55.67.168)  Accuracy: 61.0%, Avg loss: 1.057141
# (RayTrainWorker pid=103868, ip=128.55.67.168)
# (RayTrainWorker pid=103866, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=103866, ip=128.55.67.168)  Accuracy: 57.7%, Avg loss: 1.170875
# (RayTrainWorker pid=103866, ip=128.55.67.168)
# (RayTrainWorker pid=103865, ip=128.55.67.168) Test Error:
# (RayTrainWorker pid=103865, ip=128.55.67.168)  Accuracy: 59.7%, Avg loss: 1.146196
# (RayTrainWorker pid=103865, ip=128.55.67.168)
# (RayTrainWorker pid=17709) Test Error:
# (RayTrainWorker pid=17709)  Accuracy: 58.9%, Avg loss: 1.169601
# (RayTrainWorker pid=17709)
# (RayTrainWorker pid=17710) Test Error:
# (RayTrainWorker pid=17710)  Accuracy: 61.9%, Avg loss: 1.110122
# (RayTrainWorker pid=17710)
# (RayTrainWorker pid=17708) Test Error:
# (RayTrainWorker pid=17708)  Accuracy: 58.3%, Avg loss: 1.199637
# (RayTrainWorker pid=17708)
# (RayTrainWorker pid=17707) Test Error:
# (RayTrainWorker pid=17707)  Accuracy: 58.8%, Avg loss: 1.141913
# (RayTrainWorker pid=17707)
# (RayTrainWorker pid=9446, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=9446, ip=128.55.66.67)  Accuracy: 59.1%, Avg loss: 1.164412
# (RayTrainWorker pid=9446, ip=128.55.66.67)
# (RayTrainWorker pid=9445, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=9445, ip=128.55.66.67)  Accuracy: 58.0%, Avg loss: 1.149698
# (RayTrainWorker pid=9445, ip=128.55.66.67)
# (RayTrainWorker pid=9447, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=9447, ip=128.55.66.67)  Accuracy: 57.7%, Avg loss: 1.184306
# (RayTrainWorker pid=9447, ip=128.55.66.67)
# (RayTrainWorker pid=9448, ip=128.55.66.67) Test Error:
# (RayTrainWorker pid=9448, ip=128.55.66.67)  Accuracy: 58.8%, Avg loss: 1.149678
# (RayTrainWorker pid=9448, ip=128.55.66.67)

# %%
print(results.get_best_result(metric="loss", mode="min"))
# Out:
# Result(metrics={'loss': 1.1419129882540022, '_timestamp': 1679420184, '_time_this_iter_s': 19.26172709465027, '_training_iteration': 1, 'should_checkpoint': True, 'done': True, 'trial_id': '876a2_00003', 'experiment_tag': '3_lr=0.1000@perturbed[train_loop_config=lr_0_048_momentum_0_8_batch_size_1536_test_mode_False_data_dir_pscratch_sd_a_asnaylor_CIFAR10_epochs_5]'}, error=None, log_dir=PosixPath('/global/homes/a/asnaylor/ray_results/TorchTrainer_2023-03-21_10-26-33/TorchTrainer_876a2_00003_3_lr=0.1000_2023-03-21_10-28-03'))

# %% [markdown]
# ## Close cluster conection and stop job

# %%
ray.shutdown()
# Out:
# (TunerInternal pid=125486) Result for TorchTrainer_876a2_00003:
# (TunerInternal pid=125486)   _time_this_iter_s: 19.26172709465027
# (TunerInternal pid=125486)   _timestamp: 1679420184
# (TunerInternal pid=125486)   _training_iteration: 1
# (TunerInternal pid=125486)   date: 2023-03-21_10-36-24
# (TunerInternal pid=125486)   done: true
# (TunerInternal pid=125486)   experiment_id: 2f564592309a4b05aee19a4ec9d1a599
# (TunerInternal pid=125486)   hostname: nid001164
# (TunerInternal pid=125486)   iterations_since_restore: 1
# (TunerInternal pid=125486)   loss: 1.1419129882540022
# (TunerInternal pid=125486)   node_ip: nid001164
# (TunerInternal pid=125486)   pid: 17557
# (TunerInternal pid=125486)   should_checkpoint: true
# (TunerInternal pid=125486)   time_since_restore: 24.36621594429016
# (TunerInternal pid=125486)   time_this_iter_s: 24.36621594429016
# (TunerInternal pid=125486)   time_total_s: 117.50743865966797
# (TunerInternal pid=125486)   timestamp: 1679420184
# (TunerInternal pid=125486)   timesteps_since_restore: 0
# (TunerInternal pid=125486)   training_iteration: 5
# (TunerInternal pid=125486)   trial_id: 876a2_00003
# (TunerInternal pid=125486)   warmup_time: 0.3275141716003418
# (TunerInternal pid=125486)
# (TunerInternal pid=125486) Trial TorchTrainer_876a2_00003 completed.
# (TunerInternal pid=125486) 2023-03-21 10:36:24,317	INFO tune.py:798 -- Total run time: 589.28 seconds (589.22 seconds for the tuning loop).

# %%
sfp_api.delete_job(site, job['jobid'])
# Out:
# Connection to nid001164 closed by remote host.
# Connection to nid001164 closed by remote host.
# {'task_id': '0', 'status': 'OK', 'error': None}

# %% [markdown]
# ## Explore Training in Tensorboard

# %%
import nersc_tensorboard_helper
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
log_dir = str(results.get_best_result(metric="loss", mode="min").log_dir)

# %%
# %tensorboard --logdir $log_dir --port 0
# Out:
#       <iframe id="tensorboard-frame-6078813707907a89" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6078813707907a89");
#           const url = new URL("/", window.location);
#           const port = 37893;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
nersc_tensorboard_helper.tb_address()
# Out:
# <a href="https://jupyter.nersc.gov/user/asnaylor/perlmutter-shared-node-cpu/proxy/37893/">https://jupyter.nersc.gov/user/asnaylor/perlmutter-shared-node-cpu/proxy/37893/</a>
